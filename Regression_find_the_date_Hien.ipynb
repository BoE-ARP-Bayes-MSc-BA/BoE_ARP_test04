# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

from collections import Counter

# one hot encoder
from sklearn.preprocessing import OneHotEncoder
enc = OneHotEncoder(handle_unknown='ignore')

from sklearn import preprocessing
labelencoder = preprocessing.LabelEncoder()

from pygam import LinearGAM, s, f, te

# ignore warning
import warnings
from pandas.core.common import SettingWithCopyWarning
warnings.filterwarnings('ignore')

# %%
def same_direction(df, day_type):
    df_same = df[((df['WA_sentiment']<0) & (df[day_type]<0)) | ((df['WA_sentiment']>0) & (df[day_type]>0))]
    return df_same

# %% [markdown]
# # MD

# %%
df = pd.read_csv('/Users/hienanh/Downloads/regression_df_input/MD_model_df.csv')
#df_new = df[df.columns[:6]]
df_new = df.copy()
df_new['date'] = df_new['date'].astype(str)
df_new.head(5)
# Out:
#     company_name           Group ticker  \
# 0  Admiral Group  Motor/Personal  ADM.L
# 1  Admiral Group  Motor/Personal  ADM.L
# 2  Admiral Group  Motor/Personal  ADM.L
# 3  Admiral Group  Motor/Personal  ADM.L
# 4  Admiral Group  Motor/Personal  ADM.L
#
#                                            file_name        date   topic_1  \
# 0  20110302_Admiral_Group_PLC-_Earnings_Call_2011...  2011-03-02  0.000940
# 1  20110824_Admiral_Group_PLC-_Earnings_Call_2011...  2011-08-24  0.005148
# 2  20111109_Admiral_Group_PLC-_Guidance_Call_2011...  2011-11-09  0.002408
# 3  20111109_Admiral_Group_PLC-_Guidance_Call_2011...  2011-11-09  0.004044
# 4  20120307_Admiral_Group_PLC-_Earnings_Call_2012...  2012-03-07  0.019652
#
#     topic_2   topic_3   topic_4   topic_5   topic_6   topic_7   topic_8  \
# 0  0.012294  0.398791  0.008481  0.009419  0.056247  0.005848  0.000273
# 1  0.002558  0.314133  0.008527  0.037732  0.054996  0.000857  0.000344
# 2  0.003127  0.001132  0.088902  0.002066  0.037772  0.001742  0.000700
# 3  0.001966  0.398870  0.017938  0.009261  0.022735  0.025120  0.008021
# 4  0.017997  0.460937  0.081705  0.024005  0.007314  0.001035  0.000415
#
#     topic_9  topic_10  WA_sentiment   Close       D-1       D+1       D-2  \
# 0  0.295048  0.212659      0.000392  1655.0 -0.031030  0.013897 -0.020130
# 1  0.266681  0.309022      0.000765  1353.0 -0.118567 -0.054693 -0.110454
# 2  0.296897  0.565255     -0.000433   887.5 -0.256077 -0.076056 -0.247881
# 3  0.252457  0.259588      0.000336   887.5 -0.256077 -0.076056 -0.247881
# 4  0.162040  0.224901      0.001669  1144.0  0.100000  0.015734  0.095785
#
#         D+2       D-3       D+3       D-5       D+5      D-10      D+10  \
# 0  0.015106 -0.003612 -0.000604 -0.011350 -0.003021 -0.029326 -0.060423
# 1 -0.025868 -0.094983 -0.005913 -0.125969  0.011086 -0.031496  0.008130
# 2 -0.053521 -0.251686 -0.061972 -0.234914 -0.098028 -0.276691 -0.025352
# 3 -0.053521 -0.251686 -0.061972 -0.234914 -0.098028 -0.276691 -0.025352
# 4  0.012238  0.080264  0.022727  0.062210  0.036713  0.103182  0.020979
#
#        D-15      D+15      D-16      D+16      D-17      D+17      D-18  \
# 0 -0.030463 -0.045317 -0.034422 -0.046526 -0.037231 -0.047734 -0.028186
# 1 -0.117417 -0.028825 -0.099800 -0.041390 -0.119141 -0.056911 -0.126533
# 2 -0.275510  0.039437 -0.285427  0.027606 -0.296751  0.027042 -0.297308
# 3 -0.275510  0.039437 -0.285427  0.027606 -0.296751  0.027042 -0.297308
# 4  0.179990  0.014860  0.181818  0.009615  0.181818  0.037587  0.186722
#
#        D+18      D-19      D+19      D-20      D+20      D-21      D+21  \
# 0 -0.044713 -0.024175 -0.060423 -0.045009 -0.057402 -0.032164 -0.061027
# 1 -0.048041 -0.127097 -0.070214 -0.111038 -0.090909 -0.131579 -0.060606
# 2  0.045070 -0.284274  0.003380 -0.283118 -0.036056 -0.279041 -0.055211
# 3  0.045070 -0.284274  0.003380 -0.283118 -0.036056 -0.279041 -0.055211
# 4  0.039336  0.161421  0.055070  0.186107  0.039336  0.175745  0.055070
#
#        D-22      D+22      D-23      D+23      D-24      D+24      D-25  \
# 0  0.007304 -0.026586  0.010996 -0.026586 -0.003012 -0.028399 -0.001809
# 1 -0.133803 -0.014782 -0.151192  0.021434 -0.147985 -0.025129 -0.128783
# 2 -0.287721 -0.037183 -0.283118 -0.070986 -0.295075 -0.067042 -0.297308
# 3 -0.287721 -0.037183 -0.283118 -0.070986 -0.295075 -0.067042 -0.297308
# 4  0.145719  0.044580  0.102119  0.051573  0.189189  0.063811  0.226152
#
#        D+25      D-26      D+26      D-27      D+27      D-28      D+28  \
# 0 -0.021752  0.010996 -0.031420  0.003639 -0.025378 -0.000604 -0.025378
# 1 -0.035477 -0.127097 -0.066519 -0.118567 -0.070214 -0.146910 -0.093126
# 2 -0.113239 -0.276691 -0.098028 -0.294515 -0.096338 -0.297308 -0.098592
# 3 -0.113239 -0.276691 -0.098028 -0.294515 -0.096338 -0.297308 -0.098592
# 4  0.034091  0.215728  0.026224  0.278927  0.045455  0.242803  0.056818
#
#        D-29      D+29      D-30      D+30      D-40      D+40      D-50  \
# 0  0.020345 -0.028399  0.022236 -0.015710  0.057508  0.022356  0.067054
# 1 -0.143129 -0.066519 -0.125404 -0.069475 -0.178007 -0.108647 -0.208309
# 2 -0.319923 -0.061408 -0.327142 -0.077183 -0.303375 -0.069859 -0.349817
# 3 -0.319923 -0.061408 -0.327142 -0.077183 -0.303375 -0.069859 -0.349817
# 4  0.243478  0.056818  0.266888  0.070804  0.354648  0.013986  0.375827
#
#        D+50      D-60      D+60
# 0  0.059819  0.030511  0.041088
# 1 -0.124169 -0.205520 -0.390244
# 2  0.018028 -0.420314  0.125070
# 3  0.018028 -0.420314  0.125070
# 4 -0.048951  0.338795 -0.055944

# %%
# day_list = df_new.iloc[:,17:66].columns.to_list()

# %%
# for day in day_list:
#     print(f"------------- {day}")
#     df_run = same_direction(df_new, day)
#     df_run['group'] = labelencoder.fit_transform(df_run['Group'])

#     X = df_run[['WA_sentiment','group']].values.tolist()
#     Y = df_run[day]

#     gam = LinearGAM(s(0)+f(1)).fit(X, Y)
#     print(gam.summary())
#     print("                      ")

# %%
X_col = ['WA_sentiment']
df_dummies = pd.get_dummies(df_new,prefix=['Group'], columns = ['Group'], drop_first=False)
dummies_category = df_dummies.columns[-10:]
X_col.extend(dummies_category)
print(X_col)

day_list = df_new.columns[17:].tolist()
print(day_list)
# Out:
# ['WA_sentiment', 'Group_European (Re)Insurers', 'Group_Global Commercial', 'Group_Japanese & Pacific', 'Group_LN Equity', 'Group_Life Groups & Retail Life', 'Group_London Market', 'Group_Motor/Personal', 'Group_Other insurers', 'Group_Run-off', 'Group_US - Specialty/P&C/Reinsurance']
# ['D-1', 'D+1', 'D-2', 'D+2', 'D-3', 'D+3', 'D-5', 'D+5', 'D-10', 'D+10', 'D-15', 'D+15', 'D-16', 'D+16', 'D-17', 'D+17', 'D-18', 'D+18', 'D-19', 'D+19', 'D-20', 'D+20', 'D-21', 'D+21', 'D-22', 'D+22', 'D-23', 'D+23', 'D-24', 'D+24', 'D-25', 'D+25', 'D-26', 'D+26', 'D-27', 'D+27', 'D-28', 'D+28', 'D-29', 'D+29', 'D-30', 'D+30', 'D-40', 'D+40', 'D-50', 'D+50', 'D-60', 'D+60']

# %%
formula = 's(WA_sentiment) '
for cat in dummies_category:
    new_var = f'+ s({cat}) + te(WA_sentiment,{cat})'
    formula += new_var
print(formula)

for day in day_list:
    print(f"------------- {day}")
    df_run = same_direction(df_dummies, day)
    # df_run['group'] = labelencoder.fit_transform(df_run['Group'])

    X = df_run[X_col].values.tolist()
    Y = df_run[day]

    gam = LinearGAM(s(0, n_splines=300) + s(1) + te(0,1)+ s(2) + te(0,2)+ s(3) + te(0,3)+ s(4) + te(0,4)
                    + s(5) + te(0,5)+ s(6) + te(0,6)+ s(7) + te(0,7)+ s(8) + te(0,8)
                    + s(9) + te(0,9)+ s(10) + te(0,10)).fit(X, Y)
    print(gam.summary())
    print("                      ")
# Out:
# s(WA_sentiment) + s(Group_European (Re)Insurers) + te(WA_sentiment,Group_European (Re)Insurers)+ s(Group_Global Commercial) + te(WA_sentiment,Group_Global Commercial)+ s(Group_Japanese & Pacific) + te(WA_sentiment,Group_Japanese & Pacific)+ s(Group_LN Equity) + te(WA_sentiment,Group_LN Equity)+ s(Group_Life Groups & Retail Life) + te(WA_sentiment,Group_Life Groups & Retail Life)+ s(Group_London Market) + te(WA_sentiment,Group_London Market)+ s(Group_Motor/Personal) + te(WA_sentiment,Group_Motor/Personal)+ s(Group_Other insurers) + te(WA_sentiment,Group_Other insurers)+ s(Group_Run-off) + te(WA_sentiment,Group_Run-off)+ s(Group_US - Specialty/P&C/Reinsurance) + te(WA_sentiment,Group_US - Specialty/P&C/Reinsurance)
# ------------- D-1
# LinearGAM
# =============================================== ==========================================================
# Distribution:                        NormalDist Effective DoF:                                     49.9141
# Link Function:                     IdentityLink Log Likelihood:                               -816701.9001
# Number of Samples:                          966 AIC:                                          1633505.6285
#                                                 AICc:                                         1633511.4117
#                                                 GCV:                                                0.0006
#                                                 Scale:                                              0.0006
#                                                 Pseudo R-Squared:                                   0.2502
# ==========================================================================================================
# Feature Function                  Lambda               Rank         EDoF         P > x        Sig. Code
# ================================= ==================== ============ ============ ============ ============
# s(0)                              [0.6]                300                       1.11e-16     ***
# s(1)                              [0.6]                20                        1.11e-16     ***
# te(0, 1)                          [0.6 0.6]            100                       1.11e-16     ***
# s(2)                              [0.6]                20                        1.11e-16     ***
# te(0, 2)                          [0.6 0.6]            100                       1.11e-16     ***
# s(3)                              [0.6]                20                        1.11e-16     ***
# te(0, 3)                          [0.6 0.6]            100                       1.11e-16     ***
# s(4)                              [0.6]                20                        1.11e-16     ***
# te(0, 4)                          [0.6 0.6]            100                       1.11e-16     ***
# s(5)                              [0.6]                20                        1.11e-16     ***
# te(0, 5)                          [0.6 0.6]            100                       1.11e-16     ***
# s(6)                              [0.6]                20                        1.11e-16     ***
# te(0, 6)                          [0.6 0.6]            100                       1.11e-16     ***
# s(7)                              [0.6]                20                        1.11e-16     ***
# te(0, 7)                          [0.6 0.6]            100                       1.11e-16     ***
# s(8)                              [0.6]                20                        1.11e-16     ***
# te(0, 8)                          [0.6 0.6]            100                       1.11e-16     ***
# s(9)                              [0.6]                20                        1.11e-16     ***
# te(0, 9)                          [0.6 0.6]            100                       1.11e-16     ***
# s(10)                             [0.6]                20                        1.11e-16     ***
# te(0, 10)                         [0.6 0.6]            100                       1.11e-16     ***
# intercept                                              1                         1.07e-01
# ==========================================================================================================
# Significance codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# WARNING: Fitting splines and a linear function to a feature introduces a model identifiability problem
#          which can cause p-values to appear significant when they are not.
#
# WARNING: p-values calculated in this manner behave correctly for un-penalized models or models with
#          known smoothing parameters, but when smoothing parameters have been estimated, the p-values
#          are typically lower than they should be, meaning that the tests reject the null too readily.
# None
#
# ------------- D+1
# LinearGAM
# =============================================== ==========================================================
# Distribution:                        NormalDist Effective DoF:                                     48.1798
# Link Function:                     IdentityLink Log Likelihood:                              -1685404.6934
# Number of Samples:                          948 AIC:                                          3370907.7464
#                                                 AICc:                                         3370913.2438
#                                                 GCV:                                                0.0003
#                                                 Scale:                                              0.0003
#                                                 Pseudo R-Squared:                                   0.2602
# ==========================================================================================================
# Feature Function                  Lambda               Rank         EDoF         P > x        Sig. Code
# ================================= ==================== ============ ============ ============ ============
# s(0)                              [0.6]                300                       1.11e-16     ***
# s(1)                              [0.6]                20                        1.11e-16     ***
# te(0, 1)                          [0.6 0.6]            100                       1.11e-16     ***
# s(2)                              [0.6]                20                        1.11e-16     ***
# te(0, 2)                          [0.6 0.6]            100                       1.11e-16     ***
# s(3)                              [0.6]                20                        1.11e-16     ***
# te(0, 3)                          [0.6 0.6]            100                       1.11e-16     ***
# s(4)                              [0.6]                20                        1.11e-16     ***
# te(0, 4)                          [0.6 0.6]            100                       1.11e-16     ***
# s(5)                              [0.6]                20                        1.11e-16     ***
# te(0, 5)                          [0.6 0.6]            100                       1.11e-16     ***
# s(6)                              [0.6]                20                        1.11e-16     ***
# te(0, 6)                          [0.6 0.6]            100                       1.11e-16     ***
# s(7)                              [0.6]                20                        1.11e-16     ***
# te(0, 7)                          [0.6 0.6]            100                       1.11e-16     ***
# s(8)                              [0.6]                20                        1.11e-16     ***
# te(0, 8)                          [0.6 0.6]            100                       1.11e-16     ***
# s(9)                              [0.6]                20                        1.11e-16     ***
# te(0, 9)                          [0.6 0.6]            100                       1.11e-16     ***
# s(10)                             [0.6]                20                        1.11e-16     ***
# te(0, 10)                         [0.6 0.6]            100                       1.11e-16     ***
# intercept                                              1                         5.08e-02     .
# ==========================================================================================================
# Significance codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# WARNING: Fitting splines and a linear function to a feature introduces a model identifiability problem
#          which can cause p-values to appear significant when they are not.
#
# WARNING: p-values calculated in this manner behave correctly for un-penalized models or models with
#          known smoothing parameters, but when smoothing parameters have been estimated, the p-values
#          are typically lower than they should be, meaning that the tests reject the null too readily.
# None
#
# ------------- D-2
# LinearGAM
# =============================================== ==========================================================
# Distribution:                        NormalDist Effective DoF:                                     50.1764
# Link Function:                     IdentityLink Log Likelihood:                               -644776.8687
# Number of Samples:                          969 AIC:                                          1289656.0902
#                                                 AICc:                                         1289661.9151
#                                                 GCV:                                                0.0008
#                                                 Scale:                                              0.0007
#                                                 Pseudo R-Squared:                                   0.2222
# ==========================================================================================================
# Feature Function                  Lambda               Rank         EDoF         P > x        Sig. Code
# ================================= ==================== ============ ============ ============ ============
# s(0)                              [0.6]                300                       1.11e-16     ***
# s(1)                              [0.6]                20                        1.11e-16     ***
# te(0, 1)                          [0.6 0.6]            100                       1.11e-16     ***
# s(2)                              [0.6]                20                        1.11e-16     ***
# te(0, 2)                          [0.6 0.6]            100                       1.11e-16     ***
# s(3)                              [0.6]                20                        1.11e-16     ***
# te(0, 3)                          [0.6 0.6]            100                       1.11e-16     ***
# s(4)                              [0.6]                20                        1.11e-16     ***
# te(0, 4)                          [0.6 0.6]            100                       1.11e-16     ***
# s(5)                              [0.6]                20                        1.11e-16     ***
# te(0, 5)                          [0.6 0.6]            100                       1.11e-16     ***
# s(6)                              [0.6]                20                        1.11e-16     ***
# te(0, 6)                          [0.6 0.6]            100                       1.11e-16     ***
# s(7)                              [0.6]                20                        1.11e-16     ***
# te(0, 7)                          [0.6 0.6]            100                       1.11e-16     ***
# s(8)                              [0.6]                20                        1.11e-16     ***
# te(0, 8)                          [0.6 0.6]            100                       1.11e-16     ***
# s(9)                              [0.6]                20                        1.11e-16     ***
# te(0, 9)                          [0.6 0.6]            100                       1.11e-16     ***
# s(10)                             [0.6]                20                        1.11e-16     ***
# te(0, 10)                         [0.6 0.6]            100                       1.11e-16     ***
# intercept                                              1                         1.00e-01
# ==========================================================================================================
# Significance codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# WARNING: Fitting splines and a linear function to a feature introduces a model identifiability problem
#          which can cause p-values to appear significant when they are not.
#
# WARNING: p-values calculated in this manner behave correctly for un-penalized models or models with
#          known smoothing parameters, but when smoothing parameters have been estimated, the p-values
#          are typically lower than they should be, meaning that the tests reject the null too readily.
# None
#
# ------------- D+2
# LinearGAM
# =============================================== ==========================================================
# Distribution:                        NormalDist Effective DoF:                                     43.6973
# Link Function:                     IdentityLink Log Likelihood:                              -1083453.8126
# Number of Samples:                          957 AIC:                                          2166997.0197
#                                                 AICc:                                         2167001.5024
#                                                 GCV:                                                0.0005
#                                                 Scale:                                              0.0004
#                                                 Pseudo R-Squared:                                   0.2425
# ==========================================================================================================
# Feature Function                  Lambda               Rank         EDoF         P > x        Sig. Code
# ================================= ==================== ============ ============ ============ ============
# s(0)                              [0.6]                300                       1.11e-16     ***
# s(1)                              [0.6]                20                        1.11e-16     ***
# te(0, 1)                          [0.6 0.6]            100                       1.11e-16     ***
# s(2)                              [0.6]                20                        1.11e-16     ***
# te(0, 2)                          [0.6 0.6]            100                       1.11e-16     ***
# s(3)                              [0.6]                20                        1.11e-16     ***
# te(0, 3)                          [0.6 0.6]            100                       1.11e-16     ***
# s(4)                              [0.6]                20                        1.11e-16     ***
# te(0, 4)                          [0.6 0.6]            100                       1.11e-16     ***
# s(5)                              [0.6]                20                        1.11e-16     ***
# te(0, 5)                          [0.6 0.6]            100                       1.11e-16     ***
# s(6)                              [0.6]                20                        1.11e-16     ***
# te(0, 6)                          [0.6 0.6]            100                       1.11e-16     ***
# s(7)                              [0.6]                20                        1.11e-16     ***
# te(0, 7)                          [0.6 0.6]            100                       1.11e-16     ***
# s(8)                              [0.6]                20                        1.11e-16     ***
# te(0, 8)                          [0.6 0.6]            100                       1.11e-16     ***
# s(9)                              [0.6]                20                        1.11e-16     ***
# te(0, 9)                          [0.6 0.6]            100                       1.11e-16     ***
# s(10)                             [0.6]                20                        1.11e-16     ***
# te(0, 10)                         [0.6 0.6]            100                       1.11e-16     ***
# intercept                                              1                         1.62e-01
# ==========================================================================================================
# Significance codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# WARNING: Fitting splines and a linear function to a feature introduces a model identifiability problem
#          which can cause p-values to appear significant when they are not.
#
# WARNING: p-values calculated in this manner behave correctly for un-penalized models or models with
#          known smoothing parameters, but when smoothing parameters have been estimated, the p-values
#          are typically lower than they should be, meaning that the tests reject the null too readily.
# None
#
# ------------- D-3
# LinearGAM
# =============================================== ==========================================================
# Distribution:                        NormalDist Effective DoF:                                     49.1432
# Link Function:                     IdentityLink Log Likelihood:                               -567925.1828
# Number of Samples:                          970 AIC:                                          1135950.6521
#                                                 AICc:                                          1135956.234
#                                                 GCV:                                                0.0009
#                                                 Scale:                                              0.0008
#                                                 Pseudo R-Squared:                                   0.2266
# ==========================================================================================================
# Feature Function                  Lambda               Rank         EDoF         P > x        Sig. Code
# ================================= ==================== ============ ============ ============ ============
# s(0)                              [0.6]                300                       1.11e-16     ***
# s(1)                              [0.6]                20                        1.11e-16     ***
# te(0, 1)                          [0.6 0.6]            100                       1.11e-16     ***
# s(2)                              [0.6]                20                        1.11e-16     ***
# te(0, 2)                          [0.6 0.6]            100                       1.11e-16     ***
# s(3)                              [0.6]                20                        1.11e-16     ***
# te(0, 3)                          [0.6 0.6]            100                       1.11e-16     ***
# s(4)                              [0.6]                20                        1.11e-16     ***
# te(0, 4)                          [0.6 0.6]            100                       1.11e-16     ***
# s(5)                              [0.6]                20                        1.11e-16     ***
# te(0, 5)                          [0.6 0.6]            100                       1.11e-16     ***
# s(6)                              [0.6]                20                        1.11e-16     ***
# te(0, 6)                          [0.6 0.6]            100                       1.11e-16     ***
# s(7)                              [0.6]                20                        1.11e-16     ***
# te(0, 7)                          [0.6 0.6]            100                       1.11e-16     ***
# s(8)                              [0.6]                20                        1.11e-16     ***
# te(0, 8)                          [0.6 0.6]            100                       1.11e-16     ***
# s(9)                              [0.6]                20                        1.11e-16     ***
# te(0, 9)                          [0.6 0.6]            100                       1.11e-16     ***
# s(10)                             [0.6]                20                        1.11e-16     ***
# te(0, 10)                         [0.6 0.6]            100                       1.11e-16     ***
# intercept                                              1                         3.11e-01
# ==========================================================================================================
# Significance codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# WARNING: Fitting splines and a linear function to a feature introduces a model identifiability problem
#          which can cause p-values to appear significant when they are not.
#
# WARNING: p-values calculated in this manner behave correctly for un-penalized models or models with
#          known smoothing parameters, but when smoothing parameters have been estimated, the p-values
#          are typically lower than they should be, meaning that the tests reject the null too readily.
# None
#
# ------------- D+3
# LinearGAM
# =============================================== ==========================================================
# Distribution:                        NormalDist Effective DoF:                                     44.5085
# Link Function:                     IdentityLink Log Likelihood:                               -943585.4968
# Number of Samples:                          975 AIC:                                          1887262.0106
#                                                 AICc:                                         1887266.5697
#                                                 GCV:                                                0.0005
#                                                 Scale:                                              0.0005
#                                                 Pseudo R-Squared:                                   0.2503
# ==========================================================================================================
# Feature Function                  Lambda               Rank         EDoF         P > x        Sig. Code
# ================================= ==================== ============ ============ ============ ============
# s(0)                              [0.6]                300                       1.11e-16     ***
# s(1)                              [0.6]                20                        1.11e-16     ***
# te(0, 1)                          [0.6 0.6]            100                       1.11e-16     ***
# s(2)                              [0.6]                20                        1.11e-16     ***
# te(0, 2)                          [0.6 0.6]            100                       1.11e-16     ***
# s(3)                              [0.6]                20                        1.11e-16     ***
# te(0, 3)                          [0.6 0.6]            100                       1.11e-16     ***
# s(4)                              [0.6]                20                        1.11e-16     ***
# te(0, 4)                          [0.6 0.6]            100                       1.11e-16     ***
# s(5)                              [0.6]                20                        1.11e-16     ***
# te(0, 5)                          [0.6 0.6]            100                       1.11e-16     ***
# s(6)                              [0.6]                20                        1.11e-16     ***
# te(0, 6)                          [0.6 0.6]            100                       1.11e-16     ***
# s(7)                              [0.6]                20                        1.11e-16     ***
# te(0, 7)                          [0.6 0.6]            100                       1.11e-16     ***
# s(8)                              [0.6]                20                        1.11e-16     ***
# te(0, 8)                          [0.6 0.6]            100                       1.11e-16     ***
# s(9)                              [0.6]                20                        1.11e-16     ***
# te(0, 9)                          [0.6 0.6]            100                       1.11e-16     ***
# s(10)                             [0.6]                20                        1.11e-16     ***
# te(0, 10)                         [0.6 0.6]            100                       1.11e-16     ***
# intercept                                              1                         2.42e-02     *
# ==========================================================================================================
# Significance codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# WARNING: Fitting splines and a linear function to a feature introduces a model identifiability problem
#          which can cause p-values to appear significant when they are not.
#
# WARNING: p-values calculated in this manner behave correctly for un-penalized models or models with
#          known smoothing parameters, but when smoothing parameters have been estimated, the p-values
#          are typically lower than they should be, meaning that the tests reject the null too readily.
# None
#
# ------------- D-5
# LinearGAM
# =============================================== ==========================================================
# Distribution:                        NormalDist Effective DoF:                                     50.4496
# Link Function:                     IdentityLink Log Likelihood:                               -439102.8429
# Number of Samples:                          986 AIC:                                            878308.585
#                                                 AICc:                                          878314.3661
#                                                 GCV:                                                0.0012
#                                                 Scale:                                              0.0011
#                                                 Pseudo R-Squared:                                   0.2144
# ==========================================================================================================
# Feature Function                  Lambda               Rank         EDoF         P > x        Sig. Code
# ================================= ==================== ============ ============ ============ ============
# s(0)                              [0.6]                300                       1.11e-16     ***
# s(1)                              [0.6]                20                        1.11e-16     ***
# te(0, 1)                          [0.6 0.6]            100                       1.11e-16     ***
# s(2)                              [0.6]                20                        1.11e-16     ***
# te(0, 2)                          [0.6 0.6]            100                       1.11e-16     ***
# s(3)                              [0.6]                20                        1.11e-16     ***
# te(0, 3)                          [0.6 0.6]            100                       1.11e-16     ***
# s(4)                              [0.6]                20                        1.11e-16     ***
# te(0, 4)                          [0.6 0.6]            100                       1.11e-16     ***
# s(5)                              [0.6]                20                        1.11e-16     ***
# te(0, 5)                          [0.6 0.6]            100                       1.11e-16     ***
# s(6)                              [0.6]                20                        1.11e-16     ***
# te(0, 6)                          [0.6 0.6]            100                       1.11e-16     ***
# s(7)                              [0.6]                20                        1.11e-16     ***
# te(0, 7)                          [0.6 0.6]            100                       1.11e-16     ***
# s(8)                              [0.6]                20                        1.11e-16     ***
# te(0, 8)                          [0.6 0.6]            100                       1.11e-16     ***
# s(9)                              [0.6]                20                        1.11e-16     ***
# te(0, 9)                          [0.6 0.6]            100                       1.11e-16     ***
# s(10)                             [0.6]                20                        1.11e-16     ***
# te(0, 10)                         [0.6 0.6]            100                       1.11e-16     ***
# intercept                                              1                         3.98e-02     *
# ==========================================================================================================
# Significance codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# WARNING: Fitting splines and a linear function to a feature introduces a model identifiability problem
#          which can cause p-values to appear significant when they are not.
#
# WARNING: p-values calculated in this manner behave correctly for un-penalized models or models with
#          known smoothing parameters, but when smoothing parameters have been estimated, the p-values
#          are typically lower than they should be, meaning that the tests reject the null too readily.
# None
#
# ------------- D+5
# LinearGAM
# =============================================== ==========================================================
# Distribution:                        NormalDist Effective DoF:                                     42.9955
# Link Function:                     IdentityLink Log Likelihood:                               -674416.1557
# Number of Samples:                          958 AIC:                                          1348920.3023
#                                                 AICc:                                         1348924.6387
#                                                 GCV:                                                0.0007
#                                                 Scale:                                              0.0007
#                                                 Pseudo R-Squared:                                   0.2528
# ==========================================================================================================
# Feature Function                  Lambda               Rank         EDoF         P > x        Sig. Code
# ================================= ==================== ============ ============ ============ ============
# s(0)                              [0.6]                300                       1.11e-16     ***
# s(1)                              [0.6]                20                        1.11e-16     ***
# te(0, 1)                          [0.6 0.6]            100                       1.11e-16     ***
# s(2)                              [0.6]                20                        1.11e-16     ***
# te(0, 2)                          [0.6 0.6]            100                       1.11e-16     ***
# s(3)                              [0.6]                20                        1.11e-16     ***
# te(0, 3)                          [0.6 0.6]            100                       1.11e-16     ***
# s(4)                              [0.6]                20                        1.11e-16     ***
# te(0, 4)                          [0.6 0.6]            100                       1.11e-16     ***
# s(5)                              [0.6]                20                        1.11e-16     ***
# te(0, 5)                          [0.6 0.6]            100                       1.11e-16     ***
# s(6)                              [0.6]                20                        1.11e-16     ***
# te(0, 6)                          [0.6 0.6]            100                       1.11e-16     ***
# s(7)                              [0.6]                20                        1.11e-16     ***
# te(0, 7)                          [0.6 0.6]            100                       1.11e-16     ***
# s(8)                              [0.6]                20                        1.11e-16     ***
# te(0, 8)                          [0.6 0.6]            100                       1.11e-16     ***
# s(9)                              [0.6]                20                        1.11e-16     ***
# te(0, 9)                          [0.6 0.6]            100                       1.11e-16     ***
# s(10)                             [0.6]                20                        1.11e-16     ***
# te(0, 10)                         [0.6 0.6]            100                       1.11e-16     ***
# intercept                                              1                         5.98e-03     **
# ==========================================================================================================
# Significance codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# WARNING: Fitting splines and a linear function to a feature introduces a model identifiability problem
#          which can cause p-values to appear significant when they are not.
#
# WARNING: p-values calculated in this manner behave correctly for un-penalized models or models with
#          known smoothing parameters, but when smoothing parameters have been estimated, the p-values
#          are typically lower than they should be, meaning that the tests reject the null too readily.
# None
#
# ------------- D-10
# LinearGAM
# =============================================== ==========================================================
# Distribution:                        NormalDist Effective DoF:                                     52.8485
# Link Function:                     IdentityLink Log Likelihood:                               -289705.2964
# Number of Samples:                         1003 AIC:                                           579518.2898
#                                                 AICc:                                          579524.5199
#                                                 GCV:                                                0.0018
#                                                 Scale:                                              0.0016
#                                                 Pseudo R-Squared:                                   0.2018
# ==========================================================================================================
# Feature Function                  Lambda               Rank         EDoF         P > x        Sig. Code
# ================================= ==================== ============ ============ ============ ============
# s(0)                              [0.6]                300                       1.11e-16     ***
# s(1)                              [0.6]                20                        1.11e-16     ***
# te(0, 1)                          [0.6 0.6]            100                       1.11e-16     ***
# s(2)                              [0.6]                20                        1.11e-16     ***
# te(0, 2)                          [0.6 0.6]            100                       1.11e-16     ***
# s(3)                              [0.6]                20                        1.11e-16     ***
# te(0, 3)                          [0.6 0.6]            100                       1.11e-16     ***
# s(4)                              [0.6]                20                        1.11e-16     ***
# te(0, 4)                          [0.6 0.6]            100                       1.11e-16     ***
# s(5)                              [0.6]                20                        1.11e-16     ***
# te(0, 5)                          [0.6 0.6]            100                       1.11e-16     ***
# s(6)                              [0.6]                20                        1.11e-16     ***
# te(0, 6)                          [0.6 0.6]            100                       1.11e-16     ***
# s(7)                              [0.6]                20                        1.11e-16     ***
# te(0, 7)                          [0.6 0.6]            100                       1.11e-16     ***
# s(8)                              [0.6]                20                        1.11e-16     ***
# te(0, 8)                          [0.6 0.6]            100                       1.11e-16     ***
# s(9)                              [0.6]                20                        1.11e-16     ***
# te(0, 9)                          [0.6 0.6]            100                       1.11e-16     ***
# s(10)                             [0.6]                20                        1.11e-16     ***
# te(0, 10)                         [0.6 0.6]            100                       1.11e-16     ***
# intercept                                              1                         5.87e-02     .
# ==========================================================================================================
# Significance codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# WARNING: Fitting splines and a linear function to a feature introduces a model identifiability problem
#          which can cause p-values to appear significant when they are not.
#
# WARNING: p-values calculated in this manner behave correctly for un-penalized models or models with
#          known smoothing parameters, but when smoothing parameters have been estimated, the p-values
#          are typically lower than they should be, meaning that the tests reject the null too readily.
# None
#
# ------------- D+10
# LinearGAM
# =============================================== ==========================================================
# Distribution:                        NormalDist Effective DoF:                                     49.9727
# Link Function:                     IdentityLink Log Likelihood:                               -389689.5767
# Number of Samples:                          970 AIC:                                           779481.0989
#                                                 AICc:                                          779486.8704
#                                                 GCV:                                                0.0013
#                                                 Scale:                                              0.0012
#                                                 Pseudo R-Squared:                                   0.2547
# ==========================================================================================================
# Feature Function                  Lambda               Rank         EDoF         P > x        Sig. Code
# ================================= ==================== ============ ============ ============ ============
# s(0)                              [0.6]                300                       1.11e-16     ***
# s(1)                              [0.6]                20                        1.11e-16     ***
# te(0, 1)                          [0.6 0.6]            100                       1.11e-16     ***
# s(2)                              [0.6]                20                        1.11e-16     ***
# te(0, 2)                          [0.6 0.6]            100                       1.11e-16     ***
# s(3)                              [0.6]                20                        1.11e-16     ***
# te(0, 3)                          [0.6 0.6]            100                       1.11e-16     ***
# s(4)                              [0.6]                20                        1.11e-16     ***
# te(0, 4)                          [0.6 0.6]            100                       1.11e-16     ***
# s(5)                              [0.6]                20                        1.11e-16     ***
# te(0, 5)                          [0.6 0.6]            100                       1.11e-16     ***
# s(6)                              [0.6]                20                        1.11e-16     ***
# te(0, 6)                          [0.6 0.6]            100                       1.11e-16     ***
# s(7)                              [0.6]                20                        1.11e-16     ***
# te(0, 7)                          [0.6 0.6]            100                       1.11e-16     ***
# s(8)                              [0.6]                20                        1.11e-16     ***
# te(0, 8)                          [0.6 0.6]            100                       1.11e-16     ***
# s(9)                              [0.6]                20                        1.11e-16     ***
# te(0, 9)                          [0.6 0.6]            100                       1.11e-16     ***
# s(10)                             [0.6]                20                        1.11e-16     ***
# te(0, 10)                         [0.6 0.6]            100                       1.11e-16     ***
# intercept                                              1                         1.89e-05     ***
# ==========================================================================================================
# Significance codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# WARNING: Fitting splines and a linear function to a feature introduces a model identifiability problem
#          which can cause p-values to appear significant when they are not.
#
# WARNING: p-values calculated in this manner behave correctly for un-penalized models or models with
#          known smoothing parameters, but when smoothing parameters have been estimated, the p-values
#          are typically lower than they should be, meaning that the tests reject the null too readily.
# None
#
# ------------- D-15
# LinearGAM
# =============================================== ==========================================================
# Distribution:                        NormalDist Effective DoF:                                     53.2078
# Link Function:                     IdentityLink Log Likelihood:                               -244790.8294
# Number of Samples:                         1036 AIC:                                           489690.0743
#                                                 AICc:                                          489696.1768
#                                                 GCV:                                                0.0022
#                                                 Scale:                                               0.002
#                                                 Pseudo R-Squared:                                   0.2489
# ==========================================================================================================
# Feature Function                  Lambda               Rank         EDoF         P > x        Sig. Code
# ================================= ==================== ============ ============ ============ ============
# s(0)                              [0.6]                300                       1.11e-16     ***
# s(1)                              [0.6]                20                        1.11e-16     ***
# te(0, 1)                          [0.6 0.6]            100                       1.11e-16     ***
# s(2)                              [0.6]                20                        1.11e-16     ***
# te(0, 2)                          [0.6 0.6]            100                       1.11e-16     ***
# s(3)                              [0.6]                20                        1.11e-16     ***
# te(0, 3)                          [0.6 0.6]            100                       1.11e-16     ***
# s(4)                              [0.6]                20                        1.11e-16     ***
# te(0, 4)                          [0.6 0.6]            100                       1.11e-16     ***
# s(5)                              [0.6]                20                        1.11e-16     ***
# te(0, 5)                          [0.6 0.6]            100                       1.11e-16     ***
# s(6)                              [0.6]                20                        1.11e-16     ***
# te(0, 6)                          [0.6 0.6]            100                       1.11e-16     ***
# s(7)                              [0.6]                20                        1.11e-16     ***
# te(0, 7)                          [0.6 0.6]            100                       1.11e-16     ***
# s(8)                              [0.6]                20                        1.11e-16     ***
# te(0, 8)                          [0.6 0.6]            100                       1.11e-16     ***
# s(9)                              [0.6]                20                        1.11e-16     ***
# te(0, 9)                          [0.6 0.6]            100                       1.11e-16     ***
# s(10)                             [0.6]                20                        1.11e-16     ***
# te(0, 10)                         [0.6 0.6]            100                       1.11e-16     ***
# intercept                                              1                         4.14e-01
# ==========================================================================================================
# Significance codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# ...
# s(1)                              [0.6]                20                        1.11e-16     ***
# te(0, 1)                          [0.6 0.6]            100                       1.11e-16     ***
# s(2)                              [0.6]                20                        1.11e-16     ***
# te(0, 2)                          [0.6 0.6]            100                       1.11e-16     ***
# s(3)                              [0.6]                20                        1.11e-16     ***
# te(0, 3)                          [0.6 0.6]            100                       1.11e-16     ***
# s(4)                              [0.6]                20                        1.11e-16     ***
# te(0, 4)                          [0.6 0.6]            100                       1.11e-16     ***
# s(5)                              [0.6]                20                        1.11e-16     ***
# te(0, 5)                          [0.6 0.6]            100                       1.11e-16     ***
# s(6)                              [0.6]                20                        1.11e-16     ***
# te(0, 6)                          [0.6 0.6]            100                       1.11e-16     ***
# s(7)                              [0.6]                20                        1.11e-16     ***
# te(0, 7)                          [0.6 0.6]            100                       1.11e-16     ***
# s(8)                              [0.6]                20                        1.11e-16     ***
# te(0, 8)                          [0.6 0.6]            100                       1.11e-16     ***
# s(9)                              [0.6]                20                        1.11e-16     ***
# te(0, 9)                          [0.6 0.6]            100                       1.11e-16     ***
# s(10)                             [0.6]                20                        1.11e-16     ***
# te(0, 10)                         [0.6 0.6]            100                       1.11e-16     ***
# intercept                                              1                         2.94e-04     ***
# ==========================================================================================================
# Significance codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# WARNING: Fitting splines and a linear function to a feature introduces a model identifiability problem
#          which can cause p-values to appear significant when they are not.
#
# WARNING: p-values calculated in this manner behave correctly for un-penalized models or models with
#          known smoothing parameters, but when smoothing parameters have been estimated, the p-values
#          are typically lower than they should be, meaning that the tests reject the null too readily.
# None
#
# ------------- D+50
# LinearGAM
# =============================================== ==========================================================
# Distribution:                        NormalDist Effective DoF:                                     55.1492
# Link Function:                     IdentityLink Log Likelihood:                               -117241.8297
# Number of Samples:                         1002 AIC:                                           234595.9577
#                                                 AICc:                                          234602.7501
#                                                 GCV:                                                0.0043
#                                                 Scale:                                              0.0039
#                                                 Pseudo R-Squared:                                   0.2204
# ==========================================================================================================
# Feature Function                  Lambda               Rank         EDoF         P > x        Sig. Code
# ================================= ==================== ============ ============ ============ ============
# s(0)                              [0.6]                300                       1.11e-16     ***
# s(1)                              [0.6]                20                        1.11e-16     ***
# te(0, 1)                          [0.6 0.6]            100                       1.11e-16     ***
# s(2)                              [0.6]                20                        1.11e-16     ***
# te(0, 2)                          [0.6 0.6]            100                       1.11e-16     ***
# s(3)                              [0.6]                20                        1.11e-16     ***
# te(0, 3)                          [0.6 0.6]            100                       1.11e-16     ***
# s(4)                              [0.6]                20                        1.11e-16     ***
# te(0, 4)                          [0.6 0.6]            100                       1.11e-16     ***
# s(5)                              [0.6]                20                        1.11e-16     ***
# te(0, 5)                          [0.6 0.6]            100                       1.11e-16     ***
# s(6)                              [0.6]                20                        1.11e-16     ***
# te(0, 6)                          [0.6 0.6]            100                       1.11e-16     ***
# s(7)                              [0.6]                20                        1.11e-16     ***
# te(0, 7)                          [0.6 0.6]            100                       1.11e-16     ***
# s(8)                              [0.6]                20                        1.11e-16     ***
# te(0, 8)                          [0.6 0.6]            100                       1.11e-16     ***
# s(9)                              [0.6]                20                        1.11e-16     ***
# te(0, 9)                          [0.6 0.6]            100                       1.11e-16     ***
# s(10)                             [0.6]                20                        1.11e-16     ***
# te(0, 10)                         [0.6 0.6]            100                       1.11e-16     ***
# intercept                                              1                         3.70e-08     ***
# ==========================================================================================================
# Significance codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# WARNING: Fitting splines and a linear function to a feature introduces a model identifiability problem
#          which can cause p-values to appear significant when they are not.
#
# WARNING: p-values calculated in this manner behave correctly for un-penalized models or models with
#          known smoothing parameters, but when smoothing parameters have been estimated, the p-values
#          are typically lower than they should be, meaning that the tests reject the null too readily.
# None
#
# ------------- D-60
# LinearGAM
# =============================================== ==========================================================
# Distribution:                        NormalDist Effective DoF:                                     65.8514
# Link Function:                     IdentityLink Log Likelihood:                                 -79518.927
# Number of Samples:                         1113 AIC:                                           159171.5568
#                                                 AICc:                                          159180.2368
#                                                 GCV:                                                 0.007
#                                                 Scale:                                              0.0062
#                                                 Pseudo R-Squared:                                   0.2748
# ==========================================================================================================
# Feature Function                  Lambda               Rank         EDoF         P > x        Sig. Code
# ================================= ==================== ============ ============ ============ ============
# s(0)                              [0.6]                300                       1.11e-16     ***
# s(1)                              [0.6]                20                        1.11e-16     ***
# te(0, 1)                          [0.6 0.6]            100                       1.11e-16     ***
# s(2)                              [0.6]                20                        1.11e-16     ***
# te(0, 2)                          [0.6 0.6]            100                       1.11e-16     ***
# s(3)                              [0.6]                20                        1.11e-16     ***
# te(0, 3)                          [0.6 0.6]            100                       1.11e-16     ***
# s(4)                              [0.6]                20                        1.11e-16     ***
# te(0, 4)                          [0.6 0.6]            100                       1.11e-16     ***
# s(5)                              [0.6]                20                        1.11e-16     ***
# te(0, 5)                          [0.6 0.6]            100                       1.11e-16     ***
# s(6)                              [0.6]                20                        1.11e-16     ***
# te(0, 6)                          [0.6 0.6]            100                       1.11e-16     ***
# s(7)                              [0.6]                20                        1.11e-16     ***
# te(0, 7)                          [0.6 0.6]            100                       1.11e-16     ***
# s(8)                              [0.6]                20                        1.11e-16     ***
# te(0, 8)                          [0.6 0.6]            100                       1.11e-16     ***
# s(9)                              [0.6]                20                        1.11e-16     ***
# te(0, 9)                          [0.6 0.6]            100                       1.11e-16     ***
# s(10)                             [0.6]                20                        1.11e-16     ***
# te(0, 10)                         [0.6 0.6]            100                       1.11e-16     ***
# intercept                                              1                         1.01e-01
# ==========================================================================================================
# Significance codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# WARNING: Fitting splines and a linear function to a feature introduces a model identifiability problem
#          which can cause p-values to appear significant when they are not.
#
# WARNING: p-values calculated in this manner behave correctly for un-penalized models or models with
#          known smoothing parameters, but when smoothing parameters have been estimated, the p-values
#          are typically lower than they should be, meaning that the tests reject the null too readily.
# None
#
# ------------- D+60
# LinearGAM
# =============================================== ==========================================================
# Distribution:                        NormalDist Effective DoF:                                     57.9906
# Link Function:                     IdentityLink Log Likelihood:                                -99143.3609
# Number of Samples:                         1024 AIC:                                           198404.7029
#                                                 AICc:                                          198412.0449
#                                                 GCV:                                                0.0052
#                                                 Scale:                                              0.0047
#                                                 Pseudo R-Squared:                                   0.2434
# ==========================================================================================================
# Feature Function                  Lambda               Rank         EDoF         P > x        Sig. Code
# ================================= ==================== ============ ============ ============ ============
# s(0)                              [0.6]                300                       1.11e-16     ***
# s(1)                              [0.6]                20                        1.11e-16     ***
# te(0, 1)                          [0.6 0.6]            100                       1.11e-16     ***
# s(2)                              [0.6]                20                        1.11e-16     ***
# te(0, 2)                          [0.6 0.6]            100                       1.11e-16     ***
# s(3)                              [0.6]                20                        1.11e-16     ***
# te(0, 3)                          [0.6 0.6]            100                       1.11e-16     ***
# s(4)                              [0.6]                20                        1.11e-16     ***
# te(0, 4)                          [0.6 0.6]            100                       1.11e-16     ***
# s(5)                              [0.6]                20                        1.11e-16     ***
# te(0, 5)                          [0.6 0.6]            100                       1.11e-16     ***
# s(6)                              [0.6]                20                        1.11e-16     ***
# te(0, 6)                          [0.6 0.6]            100                       1.11e-16     ***
# s(7)                              [0.6]                20                        1.11e-16     ***
# te(0, 7)                          [0.6 0.6]            100                       1.11e-16     ***
# s(8)                              [0.6]                20                        1.11e-16     ***
# te(0, 8)                          [0.6 0.6]            100                       1.11e-16     ***
# s(9)                              [0.6]                20                        1.11e-16     ***
# te(0, 9)                          [0.6 0.6]            100                       1.11e-16     ***
# s(10)                             [0.6]                20                        1.11e-16     ***
# te(0, 10)                         [0.6 0.6]            100                       1.11e-16     ***
# intercept                                              1                         4.82e-11     ***
# ==========================================================================================================
# Significance codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# WARNING: Fitting splines and a linear function to a feature introduces a model identifiability problem
#          which can cause p-values to appear significant when they are not.
#
# WARNING: p-values calculated in this manner behave correctly for un-penalized models or models with
#          known smoothing parameters, but when smoothing parameters have been estimated, the p-values
#          are typically lower than they should be, meaning that the tests reject the null too readily.
# None

# %%
# formula = 's(0) '
# for i in range(len(dummies_category)):
#     new_var = f'+ s({i+1}) + te(0,{i+1})'
#     formula += new_var
# formula
# Out:
# 's(0) + s(1) + te(0,1)+ s(2) + te(0,2)+ s(3) + te(0,3)+ s(4) + te(0,4)+ s(5) + te(0,5)+ s(6) + te(0,6)+ s(7) + te(0,7)+ s(8) + te(0,8)+ s(9) + te(0,9)+ s(10) + te(0,10)'

# %% [markdown]
# # QA

# %%
df = pd.read_csv('/Users/hienanh/Downloads/regression_df_input/QA_model_df.csv')
pd.set_option('display.max_columns', None)
#df_new = df[df.columns[:6]]
df_new = df.copy()
df_new['date'] = df_new['date'].astype(str)
df_new.head(5)
# Out:
#     company_name           Group ticker  \
# 0  Admiral Group  Motor/Personal  ADM.L
# 1  Admiral Group  Motor/Personal  ADM.L
# 2  Admiral Group  Motor/Personal  ADM.L
# 3  Admiral Group  Motor/Personal  ADM.L
# 4  Admiral Group  Motor/Personal  ADM.L
#
#                                            file_name        date   topic_1  \
# 0  20110302_Admiral_Group_PLC-_Earnings_Call_2011...  2011-03-02  0.031949
# 1  20110824_Admiral_Group_PLC-_Earnings_Call_2011...  2011-08-24  0.036994
# 2  20111109_Admiral_Group_PLC-_Guidance_Call_2011...  2011-11-09  0.002439
# 3  20120307_Admiral_Group_PLC-_Earnings_Call_2012...  2012-03-07  0.000834
# 4  20130306_Admiral_Group_PLC-_Earnings_Call_2013...  2013-03-06  0.022024
#
#     topic_2   topic_3   topic_4   topic_5   topic_6   topic_7   topic_8  \
# 0  0.071316  0.001887  0.044913  0.173669  0.000872  0.354589  0.062881
# 1  0.094859  0.000492  0.092420  0.268424  0.033912  0.102734  0.103290
# 2  0.032775  0.002953  0.001697  0.312097  0.030638  0.151864  0.124540
# 3  0.068388  0.001439  0.004353  0.163258  0.000731  0.430827  0.004588
# 4  0.012450  0.735922  0.015318  0.026735  0.019312  0.018163  0.021524
#
#     topic_9  topic_10  topic_11  topic_12  topic_13  topic_14  WA_sentiment  \
# 0  0.107171  0.067565  0.000753  0.027564  0.005498  0.049375      0.000826
# 1  0.000900  0.066103  0.004690  0.005994  0.056138  0.133051      0.000971
# 2  0.121835  0.129073  0.023103  0.030216  0.034974  0.001796      0.001851
# 3  0.038603  0.110456  0.023270  0.031050  0.068767  0.053438      0.001353
# 4  0.023038  0.027322  0.016677  0.022849  0.022453  0.016212     -0.046780
#
#     Close       D-1       D+1       D-2       D+2       D-3       D+3  \
# 0  1655.0 -0.031030  0.013897 -0.020130  0.015106 -0.003612 -0.000604
# 1  1353.0 -0.118567 -0.054693 -0.110454 -0.025868 -0.094983 -0.005913
# 2   887.5 -0.256077 -0.076056 -0.247881 -0.053521 -0.251686 -0.061972
# 3  1144.0  0.100000  0.015734  0.095785  0.012238  0.080264  0.022727
# 4  1334.0  0.052881  0.016492  0.045455  0.014243  0.069767  0.018741
#
#         D-5       D+5      D-10      D+10      D-15      D+15
# 0 -0.011350 -0.003021 -0.029326 -0.060423 -0.030463 -0.045317
# 1 -0.125969  0.011086 -0.031496  0.008130 -0.117417 -0.028825
# 2 -0.234914 -0.098028 -0.276691 -0.025352 -0.275510  0.039437
# 3  0.062210  0.036713  0.103182  0.020979  0.179990  0.014860
# 4  0.066347  0.006747  0.033308 -0.001499  0.044636 -0.008996

# %%
day_list = df_new.iloc[:,21:].columns.to_list()
print(day_list)
# Out:
# ['D-1', 'D+1', 'D-2', 'D+2', 'D-3', 'D+3', 'D-5', 'D+5', 'D-10', 'D+10', 'D-15', 'D+15']

# %%
day = 'D+1'
df_run = same_direction(df_new, day)
# plot the df_run["WA_sentiment"] and df_run["D-1"]
plt.plot(df_run["WA_sentiment"], df_run["D+1"], '.')
plt.show()

# %%
import plotly.express as px

# %%
fig = px.scatter(
    df_run, x='WA_sentiment', y='D+1', opacity=0.65,
    trendline='ols', trendline_color_override='darkblue',
    # trendline="rolling", trendline_options=dict(function="median", window=5)
)
fig.show()

# %%
from pygam import GAM, s, te
day = "D-1"

df_run = same_direction(df_new, day)
df_run['group'] = labelencoder.fit_transform(df_run['Group'])

X = df_run[['WA_sentiment']].values.tolist()
Y = df_run[day]

gam = LinearGAM(s(0, n_splines=500)).fit(X, Y)
gam.summary()
# Out:
# LinearGAM
# =============================================== ==========================================================
# Distribution:                        NormalDist Effective DoF:                                     44.5083
# Link Function:                     IdentityLink Log Likelihood:                               -619195.6426
# Number of Samples:                          716 AIC:                                          1238482.3018
#                                                 AICc:                                         1238488.6245
#                                                 GCV:                                                0.0006
#                                                 Scale:                                              0.0005
#                                                 Pseudo R-Squared:                                   0.1488
# ==========================================================================================================
# Feature Function                  Lambda               Rank         EDoF         P > x        Sig. Code
# ================================= ==================== ============ ============ ============ ============
# s(0)                              [0.6]                500          44.5         1.11e-16     ***
# intercept                                              1            0.0          9.57e-01
# ==========================================================================================================
# Significance codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# WARNING: Fitting splines and a linear function to a feature introduces a model identifiability problem
#          which can cause p-values to appear significant when they are not.
#
# WARNING: p-values calculated in this manner behave correctly for un-penalized models or models with
#          known smoothing parameters, but when smoothing parameters have been estimated, the p-values
#          are typically lower than they should be, meaning that the tests reject the null too readily.

# %%
plt.figure()
# fig, axs = plt.subplots(1,1)
titles = ['sentiment']
i = 0
XX = gam.generate_X_grid(term=i)
plt.plot(XX[:, i], gam.partial_dependence(term=i, X=XX))
plt.plot(XX[:, i], gam.partial_dependence(term=i, X=XX, width=.95)[1], c='r', ls='--')
# plt.set_title(titles[i])
# Out:
# [<matplotlib.lines.Line2D at 0x7f9ba224a8b0>,
#  <matplotlib.lines.Line2D at 0x7f9ba224a8e0>]

# %%
# for day in day_list:
#     print(f"------------- {day}")
#     df_run = same_direction(df_new, day)
#     df_run['group'] = labelencoder.fit_transform(df_run['Group'])

#     X = df_run[['WA_sentiment','group']].values.tolist()
#     Y = df_run[day]

#     gam = LinearGAM(s(0)+f(1)).fit(X, Y)
#     print(gam.summary())
#     print("                      ")

# %%
X_col = ['WA_sentiment']
df_dummies = pd.get_dummies(df_new,prefix=['Group'], columns = ['Group'], drop_first=False)
dummies_category = df_dummies.columns[-10:]
X_col.extend(dummies_category)
print(X_col)
print(day_list)
# Out:
# ['WA_sentiment', 'Group_European (Re)Insurers', 'Group_Global Commercial', 'Group_Japanese & Pacific', 'Group_LN Equity', 'Group_Life Groups & Retail Life', 'Group_London Market', 'Group_Motor/Personal', 'Group_Other insurers', 'Group_Run-off', 'Group_US - Specialty/P&C/Reinsurance']
# ['D-1', 'D+1', 'D-2', 'D+2', 'D-3', 'D+3', 'D-5', 'D+5', 'D-10', 'D+10', 'D-15', 'D+15']

# %%
formula = 's(WA_sentiment) '
for cat in dummies_category:
    new_var = f'+ s({cat}) + te(WA_sentiment,{cat})'
    formula += new_var
print(formula)

for day in day_list:
    print(f"------------- {day}")
    df_run = same_direction(df_dummies, day)
    # df_run['group'] = labelencoder.fit_transform(df_run['Group'])

    X = df_run[X_col].values.tolist()
    Y = df_run[day]

    gam = LinearGAM(s(0, n_splines=300) + s(1) + te(0,1)+ s(2) + te(0,2)+ s(3) + te(0,3)+ s(4) + te(0,4)
                    + s(5) + te(0,5)+ s(6) + te(0,6)+ s(7) + te(0,7)+ s(8) + te(0,8)
                    + s(9) + te(0,9)+ s(10) + te(0,10)).fit(X, Y)
    print(gam.summary())
    print("                      ")
# Out:
# s(WA_sentiment) + s(Group_European (Re)Insurers) + te(WA_sentiment,Group_European (Re)Insurers)+ s(Group_Global Commercial) + te(WA_sentiment,Group_Global Commercial)+ s(Group_Japanese & Pacific) + te(WA_sentiment,Group_Japanese & Pacific)+ s(Group_LN Equity) + te(WA_sentiment,Group_LN Equity)+ s(Group_Life Groups & Retail Life) + te(WA_sentiment,Group_Life Groups & Retail Life)+ s(Group_London Market) + te(WA_sentiment,Group_London Market)+ s(Group_Motor/Personal) + te(WA_sentiment,Group_Motor/Personal)+ s(Group_Other insurers) + te(WA_sentiment,Group_Other insurers)+ s(Group_Run-off) + te(WA_sentiment,Group_Run-off)+ s(Group_US - Specialty/P&C/Reinsurance) + te(WA_sentiment,Group_US - Specialty/P&C/Reinsurance)
# ------------- D-1
# LinearGAM
# =============================================== ==========================================================
# Distribution:                        NormalDist Effective DoF:                                     26.1077
# Link Function:                     IdentityLink Log Likelihood:                               -659030.2666
# Number of Samples:                          716 AIC:                                          1318114.7486
#                                                 AICc:                                         1318116.9638
#                                                 GCV:                                                0.0006
#                                                 Scale:                                              0.0005
#                                                 Pseudo R-Squared:                                   0.1554
# ==========================================================================================================
# Feature Function                  Lambda               Rank         EDoF         P > x        Sig. Code
# ================================= ==================== ============ ============ ============ ============
# s(0)                              [0.6]                300                       1.11e-16     ***
# s(1)                              [0.6]                20                        1.11e-16     ***
# te(0, 1)                          [0.6 0.6]            100                       1.11e-16     ***
# s(2)                              [0.6]                20                        1.11e-16     ***
# te(0, 2)                          [0.6 0.6]            100                       1.11e-16     ***
# s(3)                              [0.6]                20                        1.11e-16     ***
# te(0, 3)                          [0.6 0.6]            100                       1.11e-16     ***
# s(4)                              [0.6]                20                        1.11e-16     ***
# te(0, 4)                          [0.6 0.6]            100                       1.11e-16     ***
# s(5)                              [0.6]                20                        1.11e-16     ***
# te(0, 5)                          [0.6 0.6]            100                       1.11e-16     ***
# s(6)                              [0.6]                20                        1.11e-16     ***
# te(0, 6)                          [0.6 0.6]            100                       1.11e-16     ***
# s(7)                              [0.6]                20                        1.11e-16     ***
# te(0, 7)                          [0.6 0.6]            100                       1.11e-16     ***
# s(8)                              [0.6]                20                        1.11e-16     ***
# te(0, 8)                          [0.6 0.6]            100                       1.11e-16     ***
# s(9)                              [0.6]                20                        1.11e-16     ***
# te(0, 9)                          [0.6 0.6]            100                       1.11e-16     ***
# s(10)                             [0.6]                20                        1.11e-16     ***
# te(0, 10)                         [0.6 0.6]            100                       1.11e-16     ***
# intercept                                              1                         4.81e-01
# ==========================================================================================================
# Significance codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# WARNING: Fitting splines and a linear function to a feature introduces a model identifiability problem
#          which can cause p-values to appear significant when they are not.
#
# WARNING: p-values calculated in this manner behave correctly for un-penalized models or models with
#          known smoothing parameters, but when smoothing parameters have been estimated, the p-values
#          are typically lower than they should be, meaning that the tests reject the null too readily.
# None
#
# ------------- D+1
# LinearGAM
# =============================================== ==========================================================
# Distribution:                        NormalDist Effective DoF:                                     20.0493
# Link Function:                     IdentityLink Log Likelihood:                              -1400271.7711
# Number of Samples:                          678 AIC:                                          2800585.6409
#                                                 AICc:                                          2800587.056
#                                                 GCV:                                                0.0002
#                                                 Scale:                                              0.0002
#                                                 Pseudo R-Squared:                                   0.1149
# ==========================================================================================================
# Feature Function                  Lambda               Rank         EDoF         P > x        Sig. Code
# ================================= ==================== ============ ============ ============ ============
# s(0)                              [0.6]                300                       1.11e-16     ***
# s(1)                              [0.6]                20                        1.11e-16     ***
# te(0, 1)                          [0.6 0.6]            100                       1.11e-16     ***
# s(2)                              [0.6]                20                        1.11e-16     ***
# te(0, 2)                          [0.6 0.6]            100                       1.11e-16     ***
# s(3)                              [0.6]                20                        1.11e-16     ***
# te(0, 3)                          [0.6 0.6]            100                       1.11e-16     ***
# s(4)                              [0.6]                20                        1.11e-16     ***
# te(0, 4)                          [0.6 0.6]            100                       1.11e-16     ***
# s(5)                              [0.6]                20                        1.11e-16     ***
# te(0, 5)                          [0.6 0.6]            100                       1.11e-16     ***
# s(6)                              [0.6]                20                        1.11e-16     ***
# te(0, 6)                          [0.6 0.6]            100                       1.11e-16     ***
# s(7)                              [0.6]                20                        1.11e-16     ***
# te(0, 7)                          [0.6 0.6]            100                       1.11e-16     ***
# s(8)                              [0.6]                20                        1.11e-16     ***
# te(0, 8)                          [0.6 0.6]            100                       1.11e-16     ***
# s(9)                              [0.6]                20                        1.11e-16     ***
# te(0, 9)                          [0.6 0.6]            100                       1.11e-16     ***
# s(10)                             [0.6]                20                        1.11e-16     ***
# te(0, 10)                         [0.6 0.6]            100                       1.11e-16     ***
# intercept                                              1                         3.35e-02     *
# ==========================================================================================================
# Significance codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# WARNING: Fitting splines and a linear function to a feature introduces a model identifiability problem
#          which can cause p-values to appear significant when they are not.
#
# WARNING: p-values calculated in this manner behave correctly for un-penalized models or models with
#          known smoothing parameters, but when smoothing parameters have been estimated, the p-values
#          are typically lower than they should be, meaning that the tests reject the null too readily.
# None
#
# ------------- D-2
# LinearGAM
# =============================================== ==========================================================
# Distribution:                        NormalDist Effective DoF:                                     29.8195
# Link Function:                     IdentityLink Log Likelihood:                               -504141.3957
# Number of Samples:                          714 AIC:                                          1008344.4304
#                                                 AICc:                                         1008347.3054
#                                                 GCV:                                                0.0007
#                                                 Scale:                                              0.0007
#                                                 Pseudo R-Squared:                                   0.1496
# ==========================================================================================================
# Feature Function                  Lambda               Rank         EDoF         P > x        Sig. Code
# ================================= ==================== ============ ============ ============ ============
# s(0)                              [0.6]                300                       1.11e-16     ***
# s(1)                              [0.6]                20                        1.11e-16     ***
# te(0, 1)                          [0.6 0.6]            100                       1.11e-16     ***
# s(2)                              [0.6]                20                        1.11e-16     ***
# te(0, 2)                          [0.6 0.6]            100                       1.11e-16     ***
# s(3)                              [0.6]                20                        1.11e-16     ***
# te(0, 3)                          [0.6 0.6]            100                       1.11e-16     ***
# s(4)                              [0.6]                20                        1.11e-16     ***
# te(0, 4)                          [0.6 0.6]            100                       1.11e-16     ***
# s(5)                              [0.6]                20                        1.11e-16     ***
# te(0, 5)                          [0.6 0.6]            100                       1.11e-16     ***
# s(6)                              [0.6]                20                        1.11e-16     ***
# te(0, 6)                          [0.6 0.6]            100                       1.11e-16     ***
# s(7)                              [0.6]                20                        1.11e-16     ***
# te(0, 7)                          [0.6 0.6]            100                       1.11e-16     ***
# s(8)                              [0.6]                20                        1.11e-16     ***
# te(0, 8)                          [0.6 0.6]            100                       1.11e-16     ***
# s(9)                              [0.6]                20                        1.11e-16     ***
# te(0, 9)                          [0.6 0.6]            100                       1.11e-16     ***
# s(10)                             [0.6]                20                        1.11e-16     ***
# te(0, 10)                         [0.6 0.6]            100                       1.11e-16     ***
# intercept                                              1                         1.34e-01
# ==========================================================================================================
# Significance codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# WARNING: Fitting splines and a linear function to a feature introduces a model identifiability problem
#          which can cause p-values to appear significant when they are not.
#
# WARNING: p-values calculated in this manner behave correctly for un-penalized models or models with
#          known smoothing parameters, but when smoothing parameters have been estimated, the p-values
#          are typically lower than they should be, meaning that the tests reject the null too readily.
# None
#
# ------------- D+2
# LinearGAM
# =============================================== ==========================================================
# Distribution:                        NormalDist Effective DoF:                                     19.8742
# Link Function:                     IdentityLink Log Likelihood:                               -784282.3465
# Number of Samples:                          682 AIC:                                          1568606.4413
#                                                 AICc:                                         1568607.8247
#                                                 GCV:                                                0.0004
#                                                 Scale:                                              0.0004
#                                                 Pseudo R-Squared:                                   0.1181
# ==========================================================================================================
# Feature Function                  Lambda               Rank         EDoF         P > x        Sig. Code
# ================================= ==================== ============ ============ ============ ============
# s(0)                              [0.6]                300                       1.11e-16     ***
# s(1)                              [0.6]                20                        1.11e-16     ***
# te(0, 1)                          [0.6 0.6]            100                       1.11e-16     ***
# s(2)                              [0.6]                20                        1.11e-16     ***
# te(0, 2)                          [0.6 0.6]            100                       1.11e-16     ***
# s(3)                              [0.6]                20                        1.11e-16     ***
# te(0, 3)                          [0.6 0.6]            100                       1.11e-16     ***
# s(4)                              [0.6]                20                        1.11e-16     ***
# te(0, 4)                          [0.6 0.6]            100                       1.11e-16     ***
# s(5)                              [0.6]                20                        1.11e-16     ***
# te(0, 5)                          [0.6 0.6]            100                       1.11e-16     ***
# s(6)                              [0.6]                20                        1.11e-16     ***
# te(0, 6)                          [0.6 0.6]            100                       1.11e-16     ***
# s(7)                              [0.6]                20                        1.11e-16     ***
# te(0, 7)                          [0.6 0.6]            100                       1.11e-16     ***
# s(8)                              [0.6]                20                        1.11e-16     ***
# te(0, 8)                          [0.6 0.6]            100                       1.11e-16     ***
# s(9)                              [0.6]                20                        1.11e-16     ***
# te(0, 9)                          [0.6 0.6]            100                       1.11e-16     ***
# s(10)                             [0.6]                20                        1.11e-16     ***
# te(0, 10)                         [0.6 0.6]            100                       1.11e-16     ***
# intercept                                              1                         1.73e-03     **
# ==========================================================================================================
# Significance codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# WARNING: Fitting splines and a linear function to a feature introduces a model identifiability problem
#          which can cause p-values to appear significant when they are not.
#
# WARNING: p-values calculated in this manner behave correctly for un-penalized models or models with
#          known smoothing parameters, but when smoothing parameters have been estimated, the p-values
#          are typically lower than they should be, meaning that the tests reject the null too readily.
# None
#
# ------------- D-3
# LinearGAM
# =============================================== ==========================================================
# Distribution:                        NormalDist Effective DoF:                                     25.8655
# Link Function:                     IdentityLink Log Likelihood:                               -438565.1112
# Number of Samples:                          712 AIC:                                           877183.9533
#                                                 AICc:                                          877186.1419
#                                                 GCV:                                                0.0008
#                                                 Scale:                                              0.0008
#                                                 Pseudo R-Squared:                                   0.1469
# ==========================================================================================================
# Feature Function                  Lambda               Rank         EDoF         P > x        Sig. Code
# ================================= ==================== ============ ============ ============ ============
# s(0)                              [0.6]                300                       1.11e-16     ***
# s(1)                              [0.6]                20                        1.11e-16     ***
# te(0, 1)                          [0.6 0.6]            100                       1.11e-16     ***
# s(2)                              [0.6]                20                        1.11e-16     ***
# te(0, 2)                          [0.6 0.6]            100                       1.11e-16     ***
# s(3)                              [0.6]                20                        1.11e-16     ***
# te(0, 3)                          [0.6 0.6]            100                       1.11e-16     ***
# s(4)                              [0.6]                20                        1.11e-16     ***
# te(0, 4)                          [0.6 0.6]            100                       1.11e-16     ***
# s(5)                              [0.6]                20                        1.11e-16     ***
# te(0, 5)                          [0.6 0.6]            100                       1.11e-16     ***
# s(6)                              [0.6]                20                        1.11e-16     ***
# te(0, 6)                          [0.6 0.6]            100                       1.11e-16     ***
# s(7)                              [0.6]                20                        1.11e-16     ***
# te(0, 7)                          [0.6 0.6]            100                       1.11e-16     ***
# s(8)                              [0.6]                20                        1.11e-16     ***
# te(0, 8)                          [0.6 0.6]            100                       1.11e-16     ***
# s(9)                              [0.6]                20                        1.11e-16     ***
# te(0, 9)                          [0.6 0.6]            100                       1.11e-16     ***
# s(10)                             [0.6]                20                        1.11e-16     ***
# te(0, 10)                         [0.6 0.6]            100                       1.11e-16     ***
# intercept                                              1                         1.35e-01
# ==========================================================================================================
# Significance codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# WARNING: Fitting splines and a linear function to a feature introduces a model identifiability problem
#          which can cause p-values to appear significant when they are not.
#
# WARNING: p-values calculated in this manner behave correctly for un-penalized models or models with
#          known smoothing parameters, but when smoothing parameters have been estimated, the p-values
#          are typically lower than they should be, meaning that the tests reject the null too readily.
# None
#
# ------------- D+3
# LinearGAM
# =============================================== ==========================================================
# Distribution:                        NormalDist Effective DoF:                                     20.3677
# Link Function:                     IdentityLink Log Likelihood:                               -719040.0714
# Number of Samples:                          710 AIC:                                          1438122.8783
#                                                 AICc:                                         1438124.2684
#                                                 GCV:                                                0.0005
#                                                 Scale:                                              0.0005
#                                                 Pseudo R-Squared:                                   0.1194
# ==========================================================================================================
# Feature Function                  Lambda               Rank         EDoF         P > x        Sig. Code
# ================================= ==================== ============ ============ ============ ============
# s(0)                              [0.6]                300                       1.11e-16     ***
# s(1)                              [0.6]                20                        1.11e-16     ***
# te(0, 1)                          [0.6 0.6]            100                       1.11e-16     ***
# s(2)                              [0.6]                20                        1.11e-16     ***
# te(0, 2)                          [0.6 0.6]            100                       1.11e-16     ***
# s(3)                              [0.6]                20                        1.11e-16     ***
# te(0, 3)                          [0.6 0.6]            100                       1.11e-16     ***
# s(4)                              [0.6]                20                        1.11e-16     ***
# te(0, 4)                          [0.6 0.6]            100                       1.11e-16     ***
# s(5)                              [0.6]                20                        1.11e-16     ***
# te(0, 5)                          [0.6 0.6]            100                       1.11e-16     ***
# s(6)                              [0.6]                20                        1.11e-16     ***
# te(0, 6)                          [0.6 0.6]            100                       1.11e-16     ***
# s(7)                              [0.6]                20                        1.11e-16     ***
# te(0, 7)                          [0.6 0.6]            100                       1.11e-16     ***
# s(8)                              [0.6]                20                        1.11e-16     ***
# te(0, 8)                          [0.6 0.6]            100                       1.11e-16     ***
# s(9)                              [0.6]                20                        1.11e-16     ***
# te(0, 9)                          [0.6 0.6]            100                       1.11e-16     ***
# s(10)                             [0.6]                20                        1.11e-16     ***
# te(0, 10)                         [0.6 0.6]            100                       1.11e-16     ***
# intercept                                              1                         8.73e-04     ***
# ==========================================================================================================
# Significance codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# WARNING: Fitting splines and a linear function to a feature introduces a model identifiability problem
#          which can cause p-values to appear significant when they are not.
#
# WARNING: p-values calculated in this manner behave correctly for un-penalized models or models with
#          known smoothing parameters, but when smoothing parameters have been estimated, the p-values
#          are typically lower than they should be, meaning that the tests reject the null too readily.
# None
#
# ------------- D-5
# LinearGAM
# =============================================== ==========================================================
# Distribution:                        NormalDist Effective DoF:                                     28.1623
# Link Function:                     IdentityLink Log Likelihood:                               -364354.3917
# Number of Samples:                          748 AIC:                                           728767.1081
#                                                 AICc:                                          728769.5588
#                                                 GCV:                                                 0.001
#                                                 Scale:                                               0.001
#                                                 Pseudo R-Squared:                                   0.1504
# ==========================================================================================================
# Feature Function                  Lambda               Rank         EDoF         P > x        Sig. Code
# ================================= ==================== ============ ============ ============ ============
# s(0)                              [0.6]                300                       1.11e-16     ***
# s(1)                              [0.6]                20                        1.11e-16     ***
# te(0, 1)                          [0.6 0.6]            100                       1.11e-16     ***
# s(2)                              [0.6]                20                        1.11e-16     ***
# te(0, 2)                          [0.6 0.6]            100                       1.11e-16     ***
# s(3)                              [0.6]                20                        1.11e-16     ***
# te(0, 3)                          [0.6 0.6]            100                       1.11e-16     ***
# s(4)                              [0.6]                20                        1.11e-16     ***
# te(0, 4)                          [0.6 0.6]            100                       1.11e-16     ***
# s(5)                              [0.6]                20                        1.11e-16     ***
# te(0, 5)                          [0.6 0.6]            100                       1.11e-16     ***
# s(6)                              [0.6]                20                        1.11e-16     ***
# te(0, 6)                          [0.6 0.6]            100                       1.11e-16     ***
# s(7)                              [0.6]                20                        1.11e-16     ***
# te(0, 7)                          [0.6 0.6]            100                       1.11e-16     ***
# s(8)                              [0.6]                20                        1.11e-16     ***
# te(0, 8)                          [0.6 0.6]            100                       1.11e-16     ***
# s(9)                              [0.6]                20                        1.11e-16     ***
# te(0, 9)                          [0.6 0.6]            100                       1.11e-16     ***
# s(10)                             [0.6]                20                        1.11e-16     ***
# te(0, 10)                         [0.6 0.6]            100                       1.11e-16     ***
# intercept                                              1                         3.50e-02     *
# ==========================================================================================================
# Significance codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# WARNING: Fitting splines and a linear function to a feature introduces a model identifiability problem
#          which can cause p-values to appear significant when they are not.
#
# WARNING: p-values calculated in this manner behave correctly for un-penalized models or models with
#          known smoothing parameters, but when smoothing parameters have been estimated, the p-values
#          are typically lower than they should be, meaning that the tests reject the null too readily.
# None
#
# ------------- D+5
# LinearGAM
# =============================================== ==========================================================
# Distribution:                        NormalDist Effective DoF:                                      19.977
# Link Function:                     IdentityLink Log Likelihood:                               -543713.7998
# Number of Samples:                          684 AIC:                                          1087469.5535
#                                                 AICc:                                         1087470.9463
#                                                 GCV:                                                0.0006
#                                                 Scale:                                              0.0006
#                                                 Pseudo R-Squared:                                   0.1052
# ==========================================================================================================
# Feature Function                  Lambda               Rank         EDoF         P > x        Sig. Code
# ================================= ==================== ============ ============ ============ ============
# s(0)                              [0.6]                300                       1.11e-16     ***
# s(1)                              [0.6]                20                        1.11e-16     ***
# te(0, 1)                          [0.6 0.6]            100                       1.11e-16     ***
# s(2)                              [0.6]                20                        1.11e-16     ***
# te(0, 2)                          [0.6 0.6]            100                       1.11e-16     ***
# s(3)                              [0.6]                20                        1.11e-16     ***
# te(0, 3)                          [0.6 0.6]            100                       1.11e-16     ***
# s(4)                              [0.6]                20                        1.11e-16     ***
# te(0, 4)                          [0.6 0.6]            100                       1.11e-16     ***
# s(5)                              [0.6]                20                        1.11e-16     ***
# te(0, 5)                          [0.6 0.6]            100                       1.11e-16     ***
# s(6)                              [0.6]                20                        1.11e-16     ***
# te(0, 6)                          [0.6 0.6]            100                       1.11e-16     ***
# s(7)                              [0.6]                20                        1.11e-16     ***
# te(0, 7)                          [0.6 0.6]            100                       1.11e-16     ***
# s(8)                              [0.6]                20                        1.11e-16     ***
# te(0, 8)                          [0.6 0.6]            100                       1.11e-16     ***
# s(9)                              [0.6]                20                        1.11e-16     ***
# te(0, 9)                          [0.6 0.6]            100                       1.11e-16     ***
# s(10)                             [0.6]                20                        1.11e-16     ***
# te(0, 10)                         [0.6 0.6]            100                       1.11e-16     ***
# intercept                                              1                         7.63e-04     ***
# ==========================================================================================================
# Significance codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# WARNING: Fitting splines and a linear function to a feature introduces a model identifiability problem
#          which can cause p-values to appear significant when they are not.
#
# WARNING: p-values calculated in this manner behave correctly for un-penalized models or models with
#          known smoothing parameters, but when smoothing parameters have been estimated, the p-values
#          are typically lower than they should be, meaning that the tests reject the null too readily.
# None
#
# ------------- D-10
# LinearGAM
# =============================================== ==========================================================
# Distribution:                        NormalDist Effective DoF:                                     32.0033
# Link Function:                     IdentityLink Log Likelihood:                               -238005.2103
# Number of Samples:                          766 AIC:                                           476076.4272
#                                                 AICc:                                          476079.4934
#                                                 GCV:                                                0.0016
#                                                 Scale:                                              0.0015
#                                                 Pseudo R-Squared:                                   0.1196
# ==========================================================================================================
# Feature Function                  Lambda               Rank         EDoF         P > x        Sig. Code
# ================================= ==================== ============ ============ ============ ============
# s(0)                              [0.6]                300                       1.11e-16     ***
# s(1)                              [0.6]                20                        1.11e-16     ***
# te(0, 1)                          [0.6 0.6]            100                       1.11e-16     ***
# s(2)                              [0.6]                20                        1.11e-16     ***
# te(0, 2)                          [0.6 0.6]            100                       1.11e-16     ***
# s(3)                              [0.6]                20                        1.11e-16     ***
# te(0, 3)                          [0.6 0.6]            100                       1.11e-16     ***
# s(4)                              [0.6]                20                        1.11e-16     ***
# te(0, 4)                          [0.6 0.6]            100                       1.11e-16     ***
# s(5)                              [0.6]                20                        1.11e-16     ***
# te(0, 5)                          [0.6 0.6]            100                       1.11e-16     ***
# s(6)                              [0.6]                20                        1.11e-16     ***
# te(0, 6)                          [0.6 0.6]            100                       1.11e-16     ***
# s(7)                              [0.6]                20                        1.11e-16     ***
# te(0, 7)                          [0.6 0.6]            100                       1.11e-16     ***
# s(8)                              [0.6]                20                        1.11e-16     ***
# te(0, 8)                          [0.6 0.6]            100                       1.11e-16     ***
# s(9)                              [0.6]                20                        1.11e-16     ***
# te(0, 9)                          [0.6 0.6]            100                       1.11e-16     ***
# s(10)                             [0.6]                20                        1.11e-16     ***
# te(0, 10)                         [0.6 0.6]            100                       1.11e-16     ***
# intercept                                              1                         4.99e-03     **
# ==========================================================================================================
# Significance codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# WARNING: Fitting splines and a linear function to a feature introduces a model identifiability problem
#          which can cause p-values to appear significant when they are not.
#
# WARNING: p-values calculated in this manner behave correctly for un-penalized models or models with
#          known smoothing parameters, but when smoothing parameters have been estimated, the p-values
#          are typically lower than they should be, meaning that the tests reject the null too readily.
# None
#
# ------------- D+10
# LinearGAM
# =============================================== ==========================================================
# Distribution:                        NormalDist Effective DoF:                                     20.2349
# Link Function:                     IdentityLink Log Likelihood:                                -300421.409
# Number of Samples:                          717 AIC:                                           600885.2879
#                                                 AICc:                                          600886.6471
#                                                 GCV:                                                0.0012
#                                                 Scale:                                              0.0011
#                                                 Pseudo R-Squared:                                   0.1237
# ==========================================================================================================
# Feature Function                  Lambda               Rank         EDoF         P > x        Sig. Code
# ================================= ==================== ============ ============ ============ ============
# s(0)                              [0.6]                300                       1.11e-16     ***
# s(1)                              [0.6]                20                        1.11e-16     ***
# te(0, 1)                          [0.6 0.6]            100                       1.11e-16     ***
# s(2)                              [0.6]                20                        1.11e-16     ***
# te(0, 2)                          [0.6 0.6]            100                       1.11e-16     ***
# s(3)                              [0.6]                20                        1.11e-16     ***
# te(0, 3)                          [0.6 0.6]            100                       1.11e-16     ***
# s(4)                              [0.6]                20                        1.11e-16     ***
# te(0, 4)                          [0.6 0.6]            100                       1.11e-16     ***
# s(5)                              [0.6]                20                        1.11e-16     ***
# te(0, 5)                          [0.6 0.6]            100                       1.11e-16     ***
# s(6)                              [0.6]                20                        1.11e-16     ***
# te(0, 6)                          [0.6 0.6]            100                       1.11e-16     ***
# s(7)                              [0.6]                20                        1.11e-16     ***
# te(0, 7)                          [0.6 0.6]            100                       1.11e-16     ***
# s(8)                              [0.6]                20                        1.11e-16     ***
# te(0, 8)                          [0.6 0.6]            100                       1.11e-16     ***
# s(9)                              [0.6]                20                        1.11e-16     ***
# te(0, 9)                          [0.6 0.6]            100                       1.11e-16     ***
# s(10)                             [0.6]                20                        1.11e-16     ***
# te(0, 10)                         [0.6 0.6]            100                       1.11e-16     ***
# intercept                                              1                         4.02e-02     *
# ==========================================================================================================
# Significance codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# WARNING: Fitting splines and a linear function to a feature introduces a model identifiability problem
#          which can cause p-values to appear significant when they are not.
#
# WARNING: p-values calculated in this manner behave correctly for un-penalized models or models with
#          known smoothing parameters, but when smoothing parameters have been estimated, the p-values
#          are typically lower than they should be, meaning that the tests reject the null too readily.
# None
#
# ------------- D-15
# LinearGAM
# =============================================== ==========================================================
# Distribution:                        NormalDist Effective DoF:                                      31.457
# Link Function:                     IdentityLink Log Likelihood:                               -201341.1404
# Number of Samples:                          774 AIC:                                           402747.1949
#                                                 AICc:                                          402750.1276
#                                                 GCV:                                                0.0019
#                                                 Scale:                                              0.0018
#                                                 Pseudo R-Squared:                                   0.1151
# ==========================================================================================================
# Feature Function                  Lambda               Rank         EDoF         P > x        Sig. Code
# ================================= ==================== ============ ============ ============ ============
# s(0)                              [0.6]                300                       1.11e-16     ***
# s(1)                              [0.6]                20                        1.11e-16     ***
# te(0, 1)                          [0.6 0.6]            100                       1.11e-16     ***
# s(2)                              [0.6]                20                        1.11e-16     ***
# te(0, 2)                          [0.6 0.6]            100                       1.11e-16     ***
# s(3)                              [0.6]                20                        1.11e-16     ***
# te(0, 3)                          [0.6 0.6]            100                       1.11e-16     ***
# s(4)                              [0.6]                20                        1.11e-16     ***
# te(0, 4)                          [0.6 0.6]            100                       1.11e-16     ***
# s(5)                              [0.6]                20                        1.11e-16     ***
# te(0, 5)                          [0.6 0.6]            100                       1.11e-16     ***
# s(6)                              [0.6]                20                        1.11e-16     ***
# te(0, 6)                          [0.6 0.6]            100                       1.11e-16     ***
# s(7)                              [0.6]                20                        1.11e-16     ***
# te(0, 7)                          [0.6 0.6]            100                       1.11e-16     ***
# s(8)                              [0.6]                20                        1.11e-16     ***
# te(0, 8)                          [0.6 0.6]            100                       1.11e-16     ***
# s(9)                              [0.6]                20                        1.11e-16     ***
# te(0, 9)                          [0.6 0.6]            100                       1.11e-16     ***
# s(10)                             [0.6]                20                        1.11e-16     ***
# te(0, 10)                         [0.6 0.6]            100                       1.11e-16     ***
# intercept                                              1                         8.63e-04     ***
# ==========================================================================================================
# Significance codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# WARNING: Fitting splines and a linear function to a feature introduces a model identifiability problem
#          which can cause p-values to appear significant when they are not.
#
# WARNING: p-values calculated in this manner behave correctly for un-penalized models or models with
#          known smoothing parameters, but when smoothing parameters have been estimated, the p-values
#          are typically lower than they should be, meaning that the tests reject the null too readily.
# None
#
# ------------- D+15
# LinearGAM
# =============================================== ==========================================================
# Distribution:                        NormalDist Effective DoF:                                     20.1963
# Link Function:                     IdentityLink Log Likelihood:                               -181876.1746
# Number of Samples:                          691 AIC:                                           363794.7418
#                                                 AICc:                                          363796.1487
#                                                 GCV:                                                0.0019
#                                                 Scale:                                              0.0018
#                                                 Pseudo R-Squared:                                   0.1078
# ==========================================================================================================
# Feature Function                  Lambda               Rank         EDoF         P > x        Sig. Code
# ================================= ==================== ============ ============ ============ ============
# s(0)                              [0.6]                300                       1.11e-16     ***
# s(1)                              [0.6]                20                        1.11e-16     ***
# te(0, 1)                          [0.6 0.6]            100                       1.11e-16     ***
# s(2)                              [0.6]                20                        1.11e-16     ***
# te(0, 2)                          [0.6 0.6]            100                       1.11e-16     ***
# s(3)                              [0.6]                20                        1.11e-16     ***
# te(0, 3)                          [0.6 0.6]            100                       1.11e-16     ***
# s(4)                              [0.6]                20                        1.11e-16     ***
# te(0, 4)                          [0.6 0.6]            100                       1.11e-16     ***
# s(5)                              [0.6]                20                        1.11e-16     ***
# te(0, 5)                          [0.6 0.6]            100                       1.11e-16     ***
# s(6)                              [0.6]                20                        1.11e-16     ***
# te(0, 6)                          [0.6 0.6]            100                       1.11e-16     ***
# s(7)                              [0.6]                20                        1.11e-16     ***
# te(0, 7)                          [0.6 0.6]            100                       1.11e-16     ***
# s(8)                              [0.6]                20                        1.11e-16     ***
# te(0, 8)                          [0.6 0.6]            100                       1.11e-16     ***
# s(9)                              [0.6]                20                        1.11e-16     ***
# te(0, 9)                          [0.6 0.6]            100                       1.11e-16     ***
# s(10)                             [0.6]                20                        1.11e-16     ***
# te(0, 10)                         [0.6 0.6]            100                       1.11e-16     ***
# intercept                                              1                         1.12e-02     *
# ==========================================================================================================
# Significance codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# WARNING: Fitting splines and a linear function to a feature introduces a model identifiability problem
#          which can cause p-values to appear significant when they are not.
#
# WARNING: p-values calculated in this manner behave correctly for un-penalized models or models with
#          known smoothing parameters, but when smoothing parameters have been estimated, the p-values
#          are typically lower than they should be, meaning that the tests reject the null too readily.
# None

# %%
day = "D-1"
df_run = same_direction(df_dummies, day)
# df_run['group'] = labelencoder.fit_transform(df_run['Group'])
X = df_run[X_col].values.tolist()
Y = df_run[day]

gam = LinearGAM(s(0, n_splines=300) + s(1) + te(0,1)+ s(2) + te(0,2)+ s(3) + te(0,3)+ s(4) + te(0,4)
                    + s(5) + te(0,5)+ s(6) + te(0,6)+ s(7) + te(0,7)+ s(8) + te(0,8)
                    + s(9) + te(0,9)+ s(10) + te(0,10)).fit(X, Y)
print(gam.summary())
## plotting
plt.figure()
# fig, axs = plt.subplots(1,2)

titles = ['sentiment']
i = 0
XX = gam.generate_X_grid(term=i)
plt.plot(XX[:, i], gam.partial_dependence(term=i, X=XX))
plt.plot(XX[:, i], gam.partial_dependence(term=i, X=XX, width=.95)[1], c='r', ls='--')
# ax.set_title(titles[i])
# Out:
# LinearGAM
# =============================================== ==========================================================
# Distribution:                        NormalDist Effective DoF:                                     26.1077
# Link Function:                     IdentityLink Log Likelihood:                               -659030.2666
# Number of Samples:                          716 AIC:                                          1318114.7486
#                                                 AICc:                                         1318116.9638
#                                                 GCV:                                                0.0006
#                                                 Scale:                                              0.0005
#                                                 Pseudo R-Squared:                                   0.1554
# ==========================================================================================================
# Feature Function                  Lambda               Rank         EDoF         P > x        Sig. Code
# ================================= ==================== ============ ============ ============ ============
# s(0)                              [0.6]                300                       1.11e-16     ***
# s(1)                              [0.6]                20                        1.11e-16     ***
# te(0, 1)                          [0.6 0.6]            100                       1.11e-16     ***
# s(2)                              [0.6]                20                        1.11e-16     ***
# te(0, 2)                          [0.6 0.6]            100                       1.11e-16     ***
# s(3)                              [0.6]                20                        1.11e-16     ***
# te(0, 3)                          [0.6 0.6]            100                       1.11e-16     ***
# s(4)                              [0.6]                20                        1.11e-16     ***
# te(0, 4)                          [0.6 0.6]            100                       1.11e-16     ***
# s(5)                              [0.6]                20                        1.11e-16     ***
# te(0, 5)                          [0.6 0.6]            100                       1.11e-16     ***
# s(6)                              [0.6]                20                        1.11e-16     ***
# te(0, 6)                          [0.6 0.6]            100                       1.11e-16     ***
# s(7)                              [0.6]                20                        1.11e-16     ***
# te(0, 7)                          [0.6 0.6]            100                       1.11e-16     ***
# s(8)                              [0.6]                20                        1.11e-16     ***
# te(0, 8)                          [0.6 0.6]            100                       1.11e-16     ***
# s(9)                              [0.6]                20                        1.11e-16     ***
# te(0, 9)                          [0.6 0.6]            100                       1.11e-16     ***
# s(10)                             [0.6]                20                        1.11e-16     ***
# te(0, 10)                         [0.6 0.6]            100                       1.11e-16     ***
# intercept                                              1                         4.81e-01
# ==========================================================================================================
# Significance codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# WARNING: Fitting splines and a linear function to a feature introduces a model identifiability problem
#          which can cause p-values to appear significant when they are not.
#
# WARNING: p-values calculated in this manner behave correctly for un-penalized models or models with
#          known smoothing parameters, but when smoothing parameters have been estimated, the p-values
#          are typically lower than they should be, meaning that the tests reject the null too readily.
# None
# [<matplotlib.lines.Line2D at 0x7f9ba40466a0>,
#  <matplotlib.lines.Line2D at 0x7f9ba40466d0>]
