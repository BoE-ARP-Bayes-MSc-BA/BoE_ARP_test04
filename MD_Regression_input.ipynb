# %% [markdown]
# # MD files for regression prepration

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

from collections import Counter

import re
import string 

import nltk 
nltk.download('twitter_samples')
from nltk.corpus import twitter_samples
from nltk.corpus import stopwords          # module for stop words that come with NLTK
nltk.download('stopwords')
from nltk.stem import PorterStemmer        # module for stemming
from nltk.tokenize import TweetTokenizer   # module for tokenizing strings

# ignore warning
import warnings
from pandas.core.common import SettingWithCopyWarning
warnings.filterwarnings('ignore')

# for stock price
import yfinance as yf
from yahoofinancials import YahooFinancials
pd.set_option('display.max_columns', None)
# Out:
# [nltk_data] Downloading package twitter_samples to
# [nltk_data]     /Users/timliu/nltk_data...
# [nltk_data]   Package twitter_samples is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/timliu/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# read the csv file 
topic_modelling_df_MD22 = pd.read_csv('./main_df_output/topic_modelling_df_MD22.csv')

# %% [markdown]
# # Define Functions

# %%
# clean text
def process_text(text):
    stemmer = PorterStemmer()
    stopwords_english = stopwords.words('english')
    #text = text.str
    text = str(text)
    text = re.sub(r'\$\w*', '', text)
    text = re.sub(r'^RT[\s]+', '', text)
    text = re.sub(r'https?:\/\/.*[\r\n]*', '', text)
    text = re.sub(r'#', '', text)
    tokenizer = TweetTokenizer(preserve_case=False, strip_handles=True,reduce_len=True)
    text_tokens = tokenizer.tokenize(text)

    text_clean = []
    for word in text_tokens:
        if (word not in stopwords_english and  
                word not in string.punctuation): 
            stem_word = stemmer.stem(word)  # stemming word
            text_clean.append(stem_word)
            
    sentence = ' '.join(text_clean)
    
    return sentence

# %%
# calculate the stock price change
def stock_price_change(stock_list, start_date, end_date):
    # function for find price change
    def price_change(aapl_df, n_day):
        before = []
        after = []
        for i in range(len(aapl_df)):
            # price on that date
            prc_tdy = aapl_df['Close'][i]

            if ((i >= n_day) & 
                (i < (len(aapl_df)-n_day))):
                # price change before n_day
                prc_before = aapl_df['Close'][i-n_day]
                prc_change_before = (prc_tdy - prc_before)/prc_before
                # price change after n_day
                prc_after = aapl_df['Close'][i+n_day]
                prc_change_after = (prc_after - prc_tdy)/prc_tdy
            else:
                prc_change_before = 0
                prc_change_after = 0
            # append into list
            before.append(prc_change_before)
            after.append(prc_change_after)
        return before, after
        
    # tickers and its closing stock price
    stock_df = pd.DataFrame()
    for i in stock_list:
        aapl_df = yf.download(i, 
                        start= start_date,  # start='2010-12-01', # start 1 month before
                        end = end_date,   # end='2022-01-30', # end 1 month later
                        progress=False,)
        aapl_df = aapl_df.reset_index(drop=False)
        # add ticker name
        aapl_df['ticker']=i
        # add price change
        # aapl_df['D0'] = aapl_df['Close']
        aapl_df['D-1'],aapl_df['D+1'] = price_change(aapl_df, 1)
        aapl_df['D-2'],aapl_df['D+2'] = price_change(aapl_df, 2)
        aapl_df['D-3'],aapl_df['D+3'] = price_change(aapl_df, 3)
        aapl_df['D-5'],aapl_df['D+5'] = price_change(aapl_df, 5)
        aapl_df['D-10'],aapl_df['D+10'] = price_change(aapl_df, 10)
        aapl_df['D-15'],aapl_df['D+15'] = price_change(aapl_df, 15)
        aapl_df['D-16'],aapl_df['D+16'] = price_change(aapl_df, 16)
        aapl_df['D-17'],aapl_df['D+17'] = price_change(aapl_df, 17)
        aapl_df['D-18'],aapl_df['D+18'] = price_change(aapl_df, 18)
        aapl_df['D-19'],aapl_df['D+19'] = price_change(aapl_df, 19)
        aapl_df['D-20'],aapl_df['D+20'] = price_change(aapl_df, 20)
        aapl_df['D-21'],aapl_df['D+21'] = price_change(aapl_df, 21)
        aapl_df['D-22'],aapl_df['D+22'] = price_change(aapl_df, 22)
        aapl_df['D-23'],aapl_df['D+23'] = price_change(aapl_df, 23)
        aapl_df['D-24'],aapl_df['D+24'] = price_change(aapl_df, 24)
        aapl_df['D-25'],aapl_df['D+25'] = price_change(aapl_df, 25)
        aapl_df['D-26'],aapl_df['D+26'] = price_change(aapl_df, 26)
        aapl_df['D-27'],aapl_df['D+27'] = price_change(aapl_df, 27)
        aapl_df['D-28'],aapl_df['D+28'] = price_change(aapl_df, 28)
        aapl_df['D-29'],aapl_df['D+29'] = price_change(aapl_df, 29)
        aapl_df['D-30'],aapl_df['D+30'] = price_change(aapl_df, 30)
        aapl_df['D-40'],aapl_df['D+40'] = price_change(aapl_df, 40)
        aapl_df['D-50'],aapl_df['D+50'] = price_change(aapl_df, 50)
        aapl_df['D-60'],aapl_df['D+60'] = price_change(aapl_df, 60)
        # append into one dataframe 
        stock_df = stock_df.append(aapl_df)
        
    # drop redundancy columns
    stock_price_df = stock_df.drop(columns=['Open', 'High','Low','Adj Close','Volume'])
    stock_price_df = stock_price_df.rename(columns={'Date': 'date'})
    # drop duplicated rows
    stock_price_df = stock_price_df.drop_duplicates()
    return stock_price_df

# %% [markdown]
# # Clean text and splitting to sentence

# %%
df = topic_modelling_df_MD22.drop(['participants','idx','company_paticipants_yes','other_paticipants_yes',
                'paraghrph_noun', 'word_count', 'char_count', 'sentence_count',
                'avg_word_length', 'avg_sentence_length'], axis = 1)
df = df.rename(columns = {'paraghrph':'paraghraph','paraghrph_clean':'paraghraph_clean'})
df = df.sort_values(by=['file_name'])
df = df.reset_index(drop=True)

# splotting into the sentences
df['paraghraph'] = df['paraghraph'].apply(lambda r: r.replace("Mr. ","Mr."))
df['sentence'] = df['paraghraph'].apply(lambda r: r.split(". "))
df = df.explode('sentence')

# Apply the function to clean the text
df['clean_text'] = df['sentence'].apply(lambda r: process_text(r))
df.head(5)

df.head(5)
# Out:
#                                            file_name        date company_name  \
# 0  20110202 _Mapfre_SA_Earnings_Call_SD0000000027...  2011-02-02    Mapfre SA
# 0  20110202 _Mapfre_SA_Earnings_Call_SD0000000027...  2011-02-02    Mapfre SA
# 0  20110202 _Mapfre_SA_Earnings_Call_SD0000000027...  2011-02-02    Mapfre SA
# 0  20110202 _Mapfre_SA_Earnings_Call_SD0000000027...  2011-02-02    Mapfre SA
# 1  20110202 _Mapfre_SA_Earnings_Call_SD0000000027...  2011-02-02    Mapfre SA
#
#                                           paraghraph  \
# 0  Then the -- probably on your third question, t...
# 0  Then the -- probably on your third question, t...
# 0  Then the -- probably on your third question, t...
# 0  Then the -- probably on your third question, t...
# 1  Good afternoon, ladies and gentlemen. Welcome ...
#
#                                     paraghraph_clean   topic_1   topic_2  \
# 0  Then the -- probably on your third question th...  0.006998  0.009998
# 0  Then the -- probably on your third question th...  0.006998  0.009998
# 0  Then the -- probably on your third question th...  0.006998  0.009998
# 0  Then the -- probably on your third question th...  0.006998  0.009998
# 1  Good afternoon ladies and gentlemen Welcome to...  0.000497  0.000710
#
#     topic_3   topic_4   topic_5   topic_6   topic_7   topic_8   topic_9  \
# 0  0.017515  0.008650  0.008114  0.025534  0.006072  0.004256  0.012797
# 0  0.017515  0.008650  0.008114  0.025534  0.006072  0.004256  0.012797
# 0  0.017515  0.008650  0.008114  0.025534  0.006072  0.004256  0.012797
# 0  0.017515  0.008650  0.008114  0.025534  0.006072  0.004256  0.012797
# 1  0.136221  0.000615  0.000576  0.001814  0.000431  0.000302  0.016789
#
#    topic_10  topic_11  topic_12  topic_13  topic_14  topic_15  topic_16  \
# 0  0.007066  0.005170  0.229431  0.127076  0.013323  0.012839  0.002804
# 0  0.007066  0.005170  0.229431  0.127076  0.013323  0.012839  0.002804
# 0  0.007066  0.005170  0.229431  0.127076  0.013323  0.012839  0.002804
# 0  0.007066  0.005170  0.229431  0.127076  0.013323  0.012839  0.002804
# 1  0.000502  0.000367  0.429169  0.001088  0.000947  0.016792  0.000199
#
#    topic_17  topic_18  topic_19  topic_20  topic_21  topic_22  \
# 0  0.005600  0.461289  0.010739  0.006385  0.010984  0.007361
# 0  0.005600  0.461289  0.010739  0.006385  0.010984  0.007361
# 0  0.005600  0.461289  0.010739  0.006385  0.010984  0.007361
# 0  0.005600  0.461289  0.010739  0.006385  0.010984  0.007361
# 1  0.016277  0.135989  0.000763  0.000454  0.238974  0.000523
#
#                                             sentence  \
# 0  Then the -- probably on your third question, t...
# 0  As I was mentioning when I explained the figur...
# 0  So last year we had a negative EUR4 million an...
# 0      So that does create volatility in the result.
# 1               Good afternoon, ladies and gentlemen
#
#                                           clean_text
# 0  probabl third question volatil non-lif account...
# 0  mention explain figur forget forex big compon ...
# 0  last year neg eur 4 million year posit eur 46 ...
# 0                               creat volatil result
# 1                      good afternoon ladi gentlemen

# %% [markdown]
# # Weighted topic Probability by files

# %%
topic_df = df.copy()
# cal len paragraph
topic_df['len_para'] = topic_df['paraghraph'].apply(lambda r: len(r))

# %%
cal_len_docs = topic_df[['file_name','len_para']]
# Use GroupBy() to compute the sum of the document
cal_len_docs = cal_len_docs.groupby('file_name').sum()
cal_len_docs = cal_len_docs.rename(columns={"len_para":"len_docs"})
cal_len_docs = cal_len_docs.reset_index(drop=False)
cal_len_docs.head(5)
# Out:
#                                            file_name  len_docs
# 0  20110202 _Mapfre_SA_Earnings_Call_SD0000000027...   1425278
# 1  20110202_LEGAL_-_GEN_GRP-_Guidance_Call_2011-2...    347588
# 2  20110203_Markel_Corp-_Earnings_Call_2011-2-3_S...    885984
# 3  20110208_Beazley_PLC-_Earnings_Call_2011-2-8_S...   1391259
# 4  20110209_INTACT_FINANCIAL-_Earnings_Call_2011-...    508515

# %%
# calculate weighted average for topic probability
# -----> merge the cal_len_docs
merge_df = cal_len_docs.merge(topic_df, how='inner', on='file_name')
# -----> caculate the weight of the sentiment
merge_df['weighted']=merge_df['len_para']/merge_df['len_docs']
merge_df
# Out:
#                                                 file_name  len_docs  \
# 0       20110202 _Mapfre_SA_Earnings_Call_SD0000000027...   1425278
# 1       20110202 _Mapfre_SA_Earnings_Call_SD0000000027...   1425278
# 2       20110202 _Mapfre_SA_Earnings_Call_SD0000000027...   1425278
# 3       20110202 _Mapfre_SA_Earnings_Call_SD0000000027...   1425278
# 4       20110202 _Mapfre_SA_Earnings_Call_SD0000000027...   1425278
# ...                                                   ...       ...
# 513834  20220427_GJENSIDIGE_FORSI-_Earnings_Call_2022-...   1906758
# 513835  20220427_GJENSIDIGE_FORSI-_Earnings_Call_2022-...   1906758
# 513836  20220427_GJENSIDIGE_FORSI-_Earnings_Call_2022-...   1906758
# 513837  20220427_GJENSIDIGE_FORSI-_Earnings_Call_2022-...   1906758
# 513838  20220427_GJENSIDIGE_FORSI-_Earnings_Call_2022-...   1906758
#
#               date       company_name  \
# 0       2011-02-02          Mapfre SA
# 1       2011-02-02          Mapfre SA
# 2       2011-02-02          Mapfre SA
# 3       2011-02-02          Mapfre SA
# 4       2011-02-02          Mapfre SA
# ...            ...                ...
# 513834  2022-04-27  GJENSIDIGE FORSI-
# 513835  2022-04-27  GJENSIDIGE FORSI-
# 513836  2022-04-27  GJENSIDIGE FORSI-
# 513837  2022-04-27  GJENSIDIGE FORSI-
# 513838  2022-04-27  GJENSIDIGE FORSI-
#
#                                                paraghraph  \
# 0       Then the -- probably on your third question, t...
# 1       Then the -- probably on your third question, t...
# 2       Then the -- probably on your third question, t...
# 3       Then the -- probably on your third question, t...
# 4       Good afternoon, ladies and gentlemen. Welcome ...
# ...                                                   ...
# 513834  Yes. We got the claims inﬂation. I would start...
# 513835  Yes. We got the claims inﬂation. I would start...
# 513836  Yes. We got the claims inﬂation. I would start...
# 513837  Yes. We got the claims inﬂation. I would start...
# 513838  Yes. We got the claims inﬂation. I would start...
#
#                                          paraghraph_clean   topic_1   topic_2  \
# 0       Then the -- probably on your third question th...  0.006998  0.009998
# 1       Then the -- probably on your third question th...  0.006998  0.009998
# 2       Then the -- probably on your third question th...  0.006998  0.009998
# 3       Then the -- probably on your third question th...  0.006998  0.009998
# 4       Good afternoon ladies and gentlemen Welcome to...  0.000497  0.000710
# ...                                                   ...       ...       ...
# 513834  Yes We got the claims inﬂation I would st to s...  0.004489  0.006414
# 513835  Yes We got the claims inﬂation I would st to s...  0.004489  0.006414
# 513836  Yes We got the claims inﬂation I would st to s...  0.004489  0.006414
# 513837  Yes We got the claims inﬂation I would st to s...  0.004489  0.006414
# 513838  Yes We got the claims inﬂation I would st to s...  0.004489  0.006414
#
#          topic_3   topic_4   topic_5   topic_6   topic_7   topic_8   topic_9  \
# 0       0.017515  0.008650  0.008114  0.025534  0.006072  0.004256  0.012797
# 1       0.017515  0.008650  0.008114  0.025534  0.006072  0.004256  0.012797
# 2       0.017515  0.008650  0.008114  0.025534  0.006072  0.004256  0.012797
# 3       0.017515  0.008650  0.008114  0.025534  0.006072  0.004256  0.012797
# 4       0.136221  0.000615  0.000576  0.001814  0.000431  0.000302  0.016789
# ...          ...       ...       ...       ...       ...       ...       ...
# 513834  0.011236  0.005549  0.507074  0.374859  0.003895  0.002730  0.008210
# 513835  0.011236  0.005549  0.507074  0.374859  0.003895  0.002730  0.008210
# 513836  0.011236  0.005549  0.507074  0.374859  0.003895  0.002730  0.008210
# 513837  0.011236  0.005549  0.507074  0.374859  0.003895  0.002730  0.008210
# 513838  0.011236  0.005549  0.507074  0.374859  0.003895  0.002730  0.008210
#
#         topic_10  topic_11  topic_12  topic_13  topic_14  topic_15  topic_16  \
# 0       0.007066  0.005170  0.229431  0.127076  0.013323  0.012839  0.002804
# 1       0.007066  0.005170  0.229431  0.127076  0.013323  0.012839  0.002804
# 2       0.007066  0.005170  0.229431  0.127076  0.013323  0.012839  0.002804
# 3       0.007066  0.005170  0.229431  0.127076  0.013323  0.012839  0.002804
# 4       0.000502  0.000367  0.429169  0.001088  0.000947  0.016792  0.000199
# ...          ...       ...       ...       ...       ...       ...       ...
# 513834  0.004533  0.003317  0.003794  0.009827  0.008547  0.008237  0.001799
# 513835  0.004533  0.003317  0.003794  0.009827  0.008547  0.008237  0.001799
# 513836  0.004533  0.003317  0.003794  0.009827  0.008547  0.008237  0.001799
# 513837  0.004533  0.003317  0.003794  0.009827  0.008547  0.008237  0.001799
# 513838  0.004533  0.003317  0.003794  0.009827  0.008547  0.008237  0.001799
#
#         topic_17  topic_18  topic_19  topic_20  topic_21  topic_22  \
# 0       0.005600  0.461289  0.010739  0.006385  0.010984  0.007361
# 1       0.005600  0.461289  0.010739  0.006385  0.010984  0.007361
# 2       0.005600  0.461289  0.010739  0.006385  0.010984  0.007361
# 3       0.005600  0.461289  0.010739  0.006385  0.010984  0.007361
# 4       0.016277  0.135989  0.000763  0.000454  0.238974  0.000523
# ...          ...       ...       ...       ...       ...       ...
# 513834  0.003592  0.009145  0.006889  0.004096  0.007046  0.004722
# 513835  0.003592  0.009145  0.006889  0.004096  0.007046  0.004722
# 513836  0.003592  0.009145  0.006889  0.004096  0.007046  0.004722
# 513837  0.003592  0.009145  0.006889  0.004096  0.007046  0.004722
# 513838  0.003592  0.009145  0.006889  0.004096  0.007046  0.004722
#
#                                                  sentence  \
# 0       Then the -- probably on your third question, t...
# 1       As I was mentioning when I explained the figur...
# 2       So last year we had a negative EUR4 million an...
# 3           So that does create volatility in the result.
# 4                    Good afternoon, ladies and gentlemen
# ...                                                   ...
# 513834  So claims inﬂation so far has Company Name Gje...
# 513835  If you look forward and we always have to look...
# 513836  Its property in Norway with highest claims inﬂ...
# 513837  We expect that to be in the range between 7% a...
# 513838  And for motor, it's between 4% and 6% and that...
#
#                                                clean_text  len_para  weighted
# 0       probabl third question volatil non-lif account...       371  0.000260
# 1       mention explain figur forget forex big compon ...       371  0.000260
# 2       last year neg eur 4 million year posit eur 46 ...       371  0.000260
# 3                                    creat volatil result       371  0.000260
# 4                           good afternoon ladi gentlemen      6905  0.004845
# ...                                                   ...       ...       ...
# 513834  claim inﬂat far compani name gjensidig forsikr...       700  0.000367
# 513835   look forward alway look forward talk claim inﬂat       700  0.000367
# 513836  properti norway highest claim inﬂat driven mat...       700  0.000367
# 513837                expect rang 7 9 look 12 month ahead       700  0.000367
# 513838                 motor 4 6 that' driven wage materi       700  0.000367
#
# [513839 rows x 32 columns]

# %%
# -----> give the weighted average of the probability based on the paragraph length
for i in range (1,23):
    merge_df['topic_'+str(i)] = merge_df['topic_'+str(i)]*merge_df['weighted']
# -----> sum WA sentiment of each files
topic_df = merge_df.copy()
topic_df = topic_df.groupby(['file_name','date','company_name']).sum().reset_index(drop=False)
# drop the column: 'len_docs', 'len_para', 'weighted'
topic_df = topic_df.drop(['len_docs','len_para','weighted'], axis = 1)
topic_df
# Out:
#                                               file_name        date  \
# 0     20110202 _Mapfre_SA_Earnings_Call_SD0000000027...  2011-02-02
# 1     20110202_LEGAL_-_GEN_GRP-_Guidance_Call_2011-2...  2011-02-02
# 2     20110203_Markel_Corp-_Earnings_Call_2011-2-3_S...  2011-02-03
# 3     20110208_Beazley_PLC-_Earnings_Call_2011-2-8_S...  2011-02-08
# 4     20110209_INTACT_FINANCIAL-_Earnings_Call_2011-...  2011-02-09
# ...                                                 ...         ...
# 1984  20220310_Sanlam_Ltd-_Earnings_Call_2022-3-10_D...  2022-03-10
# 1985  20220323_Poste_Italiane_SpA-_Earnings_Call_202...  2022-03-23
# 1986  20220324_Helvetia_Holding_AG-_Earnings_Call_20...  2022-03-24
# 1987  20220426_Tryg_A-S-_Earnings_Call_2022-4-26_DN0...  2022-04-26
# 1988  20220427_GJENSIDIGE_FORSI-_Earnings_Call_2022-...  2022-04-27
#
#            company_name   topic_1   topic_2   topic_3   topic_4   topic_5  \
# 0             Mapfre SA  0.000529  0.001791  0.049546  0.001172  0.004820
# 1               LEGAL -  0.216531  0.027643  0.086830  0.016434  0.001992
# 2          Markel Corp-  0.000757  0.038224  0.236960  0.061476  0.000878
# 3          Beazley PLC-  0.002465  0.104252  0.203350  0.030701  0.000861
# 4     INTACT FINANCIAL-  0.010908  0.021243  0.190156  0.000977  0.181513
# ...                 ...       ...       ...       ...       ...       ...
# 1984        Sanlam Ltd-  0.000539  0.005307  0.047792  0.081860  0.033212
# 1985     Poste Italiane  0.000334  0.000889  0.147461  0.197865  0.006303
# 1986   Helvetia Holding  0.000327  0.000467  0.153842  0.141427  0.001050
# 1987          Tryg A-S-  0.006159  0.001081  0.015805  0.021317  0.496781
# 1988  GJENSIDIGE FORSI-  0.000690  0.000626  0.070576  0.128976  0.348964
#
#        topic_6   topic_7   topic_8   topic_9  topic_10  topic_11  topic_12  \
# 0     0.009061  0.000459  0.000893  0.025929  0.000535  0.004757  0.492328
# 1     0.019762  0.009350  0.085992  0.018523  0.001284  0.013400  0.001075
# 2     0.026811  0.000657  0.022231  0.059782  0.220587  0.008751  0.017544
# 3     0.098292  0.000645  0.021193  0.040433  0.001817  0.046452  0.011959
# 4     0.064061  0.000686  0.010780  0.012795  0.010378  0.000584  0.010786
# ...        ...       ...       ...       ...       ...       ...       ...
# 1984  0.007881  0.015709  0.001277  0.014022  0.000420  0.132473  0.029049
# 1985  0.004531  0.000751  0.000440  0.000937  0.000321  0.020527  0.035601
# 1986  0.007026  0.000283  0.000199  0.002569  0.000330  0.003159  0.106411
# 1987  0.011897  0.037108  0.001107  0.001730  0.001299  0.005372  0.000839
# 1988  0.016989  0.117122  0.000365  0.014785  0.050808  0.000492  0.000370
#
#       topic_13  topic_14  topic_15  topic_16  topic_17  topic_18  topic_19  \
# 0     0.001841  0.003557  0.005972  0.000212  0.005941  0.114924  0.001384
# 1     0.006082  0.009861  0.268015  0.000510  0.018442  0.137149  0.009010
# 2     0.147433  0.001442  0.007377  0.000778  0.000606  0.087566  0.007805
# 3     0.152928  0.022404  0.004469  0.000298  0.005535  0.124071  0.020113
# 4     0.370969  0.010725  0.016627  0.000317  0.000632  0.072174  0.007950
# ...        ...       ...       ...       ...       ...       ...       ...
# 1984  0.005603  0.010291  0.014895  0.156328  0.039353  0.048338  0.002600
# 1985  0.019539  0.012735  0.051702  0.342898  0.067181  0.065830  0.001232
# 1986  0.013529  0.003539  0.010500  0.000131  0.000261  0.000926  0.004405
# 1987  0.003077  0.036176  0.084742  0.000303  0.000605  0.200342  0.001807
# 1988  0.085222  0.002118  0.010038  0.000514  0.001185  0.027101  0.001434
#
#       topic_20  topic_21  topic_22
# 0     0.064472  0.209322  0.000557
# 1     0.003652  0.031658  0.016804
# 2     0.000691  0.001189  0.050456
# 3     0.001455  0.077473  0.028833
# 4     0.000721  0.001587  0.003430
# ...        ...       ...       ...
# 1984  0.121433  0.228233  0.003386
# 1985  0.000128  0.014635  0.008160
# 1986  0.273174  0.276102  0.000344
# 1987  0.007910  0.063745  0.000796
# 1988  0.118416  0.000687  0.002521
#
# [1989 rows x 25 columns]

# %% [markdown]
# # Weighted Sentiment Score by files

# %%
import pickle
sentiment = pickle.load(open('sentiment_model.pkl', 'rb'))
df['sentiment'] = sentiment.predict(df['clean_text'])
df.head(3)
# Out:
#                                            file_name        date company_name  \
# 0  20110202 _Mapfre_SA_Earnings_Call_SD0000000027...  2011-02-02    Mapfre SA
# 0  20110202 _Mapfre_SA_Earnings_Call_SD0000000027...  2011-02-02    Mapfre SA
# 0  20110202 _Mapfre_SA_Earnings_Call_SD0000000027...  2011-02-02    Mapfre SA
#
#                                           paraghraph  \
# 0  Then the -- probably on your third question, t...
# 0  Then the -- probably on your third question, t...
# 0  Then the -- probably on your third question, t...
#
#                                     paraghraph_clean   topic_1   topic_2  \
# 0  Then the -- probably on your third question th...  0.006998  0.009998
# 0  Then the -- probably on your third question th...  0.006998  0.009998
# 0  Then the -- probably on your third question th...  0.006998  0.009998
#
#     topic_3  topic_4   topic_5   topic_6   topic_7   topic_8   topic_9  \
# 0  0.017515  0.00865  0.008114  0.025534  0.006072  0.004256  0.012797
# 0  0.017515  0.00865  0.008114  0.025534  0.006072  0.004256  0.012797
# 0  0.017515  0.00865  0.008114  0.025534  0.006072  0.004256  0.012797
#
#    topic_10  topic_11  topic_12  topic_13  topic_14  topic_15  topic_16  \
# 0  0.007066   0.00517  0.229431  0.127076  0.013323  0.012839  0.002804
# 0  0.007066   0.00517  0.229431  0.127076  0.013323  0.012839  0.002804
# 0  0.007066   0.00517  0.229431  0.127076  0.013323  0.012839  0.002804
#
#    topic_17  topic_18  topic_19  topic_20  topic_21  topic_22  \
# 0    0.0056  0.461289  0.010739  0.006385  0.010984  0.007361
# 0    0.0056  0.461289  0.010739  0.006385  0.010984  0.007361
# 0    0.0056  0.461289  0.010739  0.006385  0.010984  0.007361
#
#                                             sentence  \
# 0  Then the -- probably on your third question, t...
# 0  As I was mentioning when I explained the figur...
# 0  So last year we had a negative EUR4 million an...
#
#                                           clean_text  sentiment
# 0  probabl third question volatil non-lif account...          1
# 0  mention explain figur forget forex big compon ...          1
# 0  last year neg eur 4 million year posit eur 46 ...          1

# %%
# Weight of each sentimentc
# cal len paragraph
df['len_para'] = df['paraghraph'].apply(lambda r: len(r))
# cal len sentence 
df['len_sent'] = df['sentence'].apply(lambda r: len(r))
df.head(3)
# Out:
#                                            file_name        date company_name  \
# 0  20110202 _Mapfre_SA_Earnings_Call_SD0000000027...  2011-02-02    Mapfre SA
# 0  20110202 _Mapfre_SA_Earnings_Call_SD0000000027...  2011-02-02    Mapfre SA
# 0  20110202 _Mapfre_SA_Earnings_Call_SD0000000027...  2011-02-02    Mapfre SA
#
#                                           paraghraph  \
# 0  Then the -- probably on your third question, t...
# 0  Then the -- probably on your third question, t...
# 0  Then the -- probably on your third question, t...
#
#                                     paraghraph_clean   topic_1   topic_2  \
# 0  Then the -- probably on your third question th...  0.006998  0.009998
# 0  Then the -- probably on your third question th...  0.006998  0.009998
# 0  Then the -- probably on your third question th...  0.006998  0.009998
#
#     topic_3  topic_4   topic_5   topic_6   topic_7   topic_8   topic_9  \
# 0  0.017515  0.00865  0.008114  0.025534  0.006072  0.004256  0.012797
# 0  0.017515  0.00865  0.008114  0.025534  0.006072  0.004256  0.012797
# 0  0.017515  0.00865  0.008114  0.025534  0.006072  0.004256  0.012797
#
#    topic_10  topic_11  topic_12  topic_13  topic_14  topic_15  topic_16  \
# 0  0.007066   0.00517  0.229431  0.127076  0.013323  0.012839  0.002804
# 0  0.007066   0.00517  0.229431  0.127076  0.013323  0.012839  0.002804
# 0  0.007066   0.00517  0.229431  0.127076  0.013323  0.012839  0.002804
#
#    topic_17  topic_18  topic_19  topic_20  topic_21  topic_22  \
# 0    0.0056  0.461289  0.010739  0.006385  0.010984  0.007361
# 0    0.0056  0.461289  0.010739  0.006385  0.010984  0.007361
# 0    0.0056  0.461289  0.010739  0.006385  0.010984  0.007361
#
#                                             sentence  \
# 0  Then the -- probably on your third question, t...
# 0  As I was mentioning when I explained the figur...
# 0  So last year we had a negative EUR4 million an...
#
#                                           clean_text  sentiment  len_para  \
# 0  probabl third question volatil non-lif account...          1       371
# 0  mention explain figur forget forex big compon ...          1       371
# 0  last year neg eur 4 million year posit eur 46 ...          1       371
#
#    len_sent
# 0       122
# 0       108
# 0        90

# %%
cal_len_docs = df[['file_name','len_para']]
# Use GroupBy() to compute the sum of the document
cal_len_docs = cal_len_docs.groupby('file_name').sum()
cal_len_docs = cal_len_docs.rename(columns={"len_para":"len_docs"})
cal_len_docs = cal_len_docs.reset_index(drop=False)
cal_len_docs.head(5)
# Out:
#                                            file_name  len_docs
# 0  20110202 _Mapfre_SA_Earnings_Call_SD0000000027...   1425278
# 1  20110202_LEGAL_-_GEN_GRP-_Guidance_Call_2011-2...    347588
# 2  20110203_Markel_Corp-_Earnings_Call_2011-2-3_S...    885984
# 3  20110208_Beazley_PLC-_Earnings_Call_2011-2-8_S...   1391259
# 4  20110209_INTACT_FINANCIAL-_Earnings_Call_2011-...    508515

# %%
# calculate weighted average for sentiment
# -----> merge the cal_len_docs
merge_df = cal_len_docs.merge(df, how='inner', on='file_name')
# -----> caculate the weight of the sentiment
merge_df['weighted']=merge_df['len_sent']/merge_df['len_docs']
# -----> give the weighted average of the sentiment score based on the sentence
merge_df['WA_sentiment'] = merge_df['weighted']*merge_df['sentiment']
# -----> sum WA sentiment of each files
sentiment_df = merge_df[['file_name','date','company_name','WA_sentiment']]
sentiment_df = sentiment_df.groupby(['file_name','date','company_name']).sum().reset_index(drop=False)
sentiment_df
# Out:
#                                               file_name        date  \
# 0     20110202 _Mapfre_SA_Earnings_Call_SD0000000027...  2011-02-02
# 1     20110202_LEGAL_-_GEN_GRP-_Guidance_Call_2011-2...  2011-02-02
# 2     20110203_Markel_Corp-_Earnings_Call_2011-2-3_S...  2011-02-03
# 3     20110208_Beazley_PLC-_Earnings_Call_2011-2-8_S...  2011-02-08
# 4     20110209_INTACT_FINANCIAL-_Earnings_Call_2011-...  2011-02-09
# ...                                                 ...         ...
# 1984  20220310_Sanlam_Ltd-_Earnings_Call_2022-3-10_D...  2022-03-10
# 1985  20220323_Poste_Italiane_SpA-_Earnings_Call_202...  2022-03-23
# 1986  20220324_Helvetia_Holding_AG-_Earnings_Call_20...  2022-03-24
# 1987  20220426_Tryg_A-S-_Earnings_Call_2022-4-26_DN0...  2022-04-26
# 1988  20220427_GJENSIDIGE_FORSI-_Earnings_Call_2022-...  2022-04-27
#
#            company_name  WA_sentiment
# 0             Mapfre SA      0.002065
# 1               LEGAL -      0.014241
# 2          Markel Corp-      0.013900
# 3          Beazley PLC-      0.008024
# 4     INTACT FINANCIAL-      0.008442
# ...                 ...           ...
# 1984        Sanlam Ltd-      0.003229
# 1985     Poste Italiane      0.002224
# 1986   Helvetia Holding      0.003615
# 1987          Tryg A-S-      0.000983
# 1988  GJENSIDIGE FORSI-      0.002621
#
# [1989 rows x 4 columns]

# %% [markdown]
# # merge the sentiment_df and topic_df together

# %%
# merge the sentiment_df and topic_df together
MD_model_df = topic_df.merge(sentiment_df, how='inner', on=['file_name','date','company_name'])
MD_model_df
# Out:
#                                               file_name        date  \
# 0     20110202 _Mapfre_SA_Earnings_Call_SD0000000027...  2011-02-02
# 1     20110202_LEGAL_-_GEN_GRP-_Guidance_Call_2011-2...  2011-02-02
# 2     20110203_Markel_Corp-_Earnings_Call_2011-2-3_S...  2011-02-03
# 3     20110208_Beazley_PLC-_Earnings_Call_2011-2-8_S...  2011-02-08
# 4     20110209_INTACT_FINANCIAL-_Earnings_Call_2011-...  2011-02-09
# ...                                                 ...         ...
# 1984  20220310_Sanlam_Ltd-_Earnings_Call_2022-3-10_D...  2022-03-10
# 1985  20220323_Poste_Italiane_SpA-_Earnings_Call_202...  2022-03-23
# 1986  20220324_Helvetia_Holding_AG-_Earnings_Call_20...  2022-03-24
# 1987  20220426_Tryg_A-S-_Earnings_Call_2022-4-26_DN0...  2022-04-26
# 1988  20220427_GJENSIDIGE_FORSI-_Earnings_Call_2022-...  2022-04-27
#
# ...        ...       ...       ...           ...
# 1984  0.121433  0.228233  0.003386      0.003229
# 1985  0.000128  0.014635  0.008160      0.002224
# 1986  0.273174  0.276102  0.000344      0.003615
# 1987  0.007910  0.063745  0.000796      0.000983
# 1988  0.118416  0.000687  0.002521      0.002621
#
# [1989 rows x 26 columns]

# %% [markdown]
# # Stock Price

# %%
# List all yahoo tickers
yahoo_ticker_list = [
    # Motor/Personal
    'ADM.L','DLG.L','SBRE.L','SAGA.L','AGS.BR',
    # Global Commercial
    'ALV.DE','CS.PA','ZURN.SW','G.MI',
    # London Market 
    'BEZ.L','HSX.L','LRE.L',
    # LN Equity 
    'LLOY.L',
    # US - Specialty/P&C/Reinsurance
    'AIG','AXS','TRV','ACGL','RNR','RE','MKL','HIG','ARGO','BRK-B','CB',
    # European (Re)Insurers
    'SCR.PA','MUV2.DE','SREN.SW','HNR1.DE',
    # Japanese & Pacific
    '8766.T','8630.T','8725.T','QBE.AX',
    # Run-off
    'ESGR','FFH.TO','RQIH.L',
    # Life Groups & Retail Life
    'PRU.L','MNG.L','LGEN.L','AV.L','PHNX.L','QLT.L','JUST.L','STJ.L','AGN.AS','DSY.JO','SLM.JO',
    # Other insurers
    'STB.OL','CNP.PA','GJF.OL','PST.MI','NN.AS','TOP.CO','BALN.SW',
    'SAMPO.HE','MAP.MC','TRYG.CO','0RHS.IL','HELN.SW','IFC.TO'
]

# Match it with company names from BoE
Insurer_Names_df = pd.read_excel('./input/Insurer_Names_for_possible_NLP_analysis.xlsx')  
Insurer_Names = Insurer_Names_df.drop(['Unnamed: 0', 'Unnamed: 4'], axis=1)
Insurer_Names = Insurer_Names.drop([0])
Insurer_Names.rename(columns={"Unnamed: 1": "Company", "Unnamed: 2": "bb ticker", "Unnamed: 3":"Group"}, inplace = True)
Insurer_Names['yahoo ticker'] = yahoo_ticker_list
Insurer_Names.head(5)
# Exported as CSV to manually matched with the extracted file names (column 'company_name' in model_df)
# Insurer_Names[['Company']].to_csv('./main_df_output/company_name_match.csv', index = False)
# Out:
#             Company bb ticker           Group yahoo ticker
# 1     ADMIRAL GROUP    ADM LN  Motor/Personal        ADM.L
# 2  DIRECT LINE INSU    DLG LN  Motor/Personal        DLG.L
# 3       SABRE INSUR   SBRE LN  Motor/Personal       SBRE.L
# 4          SAGA PLC   SAGA LN  Motor/Personal       SAGA.L
# 5             AGEAS    AGS BB  Motor/Personal       AGS.BR

# %%
company_name_match = pd.read_csv('./input/company_name_match.csv')
company_name_match.rename(columns={"Company": "company_name"}, inplace = True)
company_name_match

Groups = {
        "ADMIRAL GROUP" : "Motor/Personal", "DIRECT LINE INSU" : "Motor/Personal", 
        "SABRE INSUR" : "Motor/Personal", "SAGA PLC" : "Motor/Personal",
        "AGEAS" : "Motor/Personal",

        "ALLIANZ SE-REG" : "Global Commercial", "AXA" : "Global Commercial", 
        "ZURICH INSURANCE" : "Global Commercial", "GENERALI ASSIC" : "Global Commercial",

        "BEAZLEY PLC" : "London Market", "HISCOX LTD" : "London Market", 
        "LANCASHIRE HOLDI" : "London Market",
        
        "Society of Lloyd’s" : "LN Equity",

        "AMERICAN INTERNA" : "US - Specialty/P&C/Reinsurance", "AXIS CAPITAL" : "US - Specialty/P&C/Reinsurance",
        "TRAVELERS COS IN" : "US - Specialty/P&C/Reinsurance", "ARCH CAPITAL GRP" : "US - Specialty/P&C/Reinsurance",
        "RENAISSANCERE" : "US - Specialty/P&C/Reinsurance", "EVEREST RE GROUP" : "US - Specialty/P&C/Reinsurance",
        "MARKEL CORP" : "US - Specialty/P&C/Reinsurance", "HARTFORD FINL SV" : "US - Specialty/P&C/Reinsurance",
        "ARGO GROUP INTER" : "US - Specialty/P&C/Reinsurance", "BERKSHIRE HATH-B" : "US - Specialty/P&C/Reinsurance",
        "CHUBB LTD" : "US - Specialty/P&C/Reinsurance",

        "SCOR SE" : "European (Re)Insurers", "MUENCHENER RUE-R" : "European (Re)Insurers", 
        "SWISS RE AG" : "European (Re)Insurers", "HANNOVER RUECK S" : "European (Re)Insurers",

        "TOKIO MARINE HD" : "Japanese & Pacific", "SOMPO HOLDINGS I" : "Japanese & Pacific",
        "MS&AD INSURANCE" : "Japanese & Pacific", "QBE INSURANCE" : "Japanese & Pacific",

        "ENSTAR GROUP LTD" : "Run-off", "FAIRFAX FINL HLD" : "Run-off", "RANDALL & QUILTE" : "Run-off",

        "PRUDENTIAL PLC" : "Life Groups & Retail Life", "M&G PLC" : "Life Groups & Retail Life",
        "LEGAL & GEN GRP" : "Life Groups & Retail Life", "AVIVA PLC" : "Life Groups & Retail Life",
        "PHOENIX GROUP HO" : "Life Groups & Retail Life", "QUILTER PLC" : "Life Groups & Retail Life",
        "JUST GROUP" : "Life Groups & Retail Life", "ST JAMES'S PLACE" : "Life Groups & Retail Life",
        "AEGON NV" : "Life Groups & Retail Life", "DISCOVERY LTD" : "Life Groups & Retail Life",
        "SANLAM LTD" : "Life Groups & Retail Life",

        "STOREBRAND ASA" : "Other insurers", "CNP ASSURANCES" : "Other insurers",
        "GJENSIDIGE FORSI" : "Other insurers", "POSTE ITALIANE" : "Other insurers",
        "NN GROUP" : "Other insurers", "TOPDANMARK A/S" : "Other insurers",
        "BALOISE HOL-REG" : "Other insurers", "SAMPO OYJ-A SHS" : "Other insurers",
        "MAPFRE SA" : "Other insurers", "TRYG A/S" : "Other insurers",
        "ASR NEDERLAND NV" : "Other insurers", "HELVETIA HOL-REG" : "Other insurers",
        "INTACT FINANCIAL" : "Other insurers"
}

yahoo_ticker = {
        "ADMIRAL GROUP" : "ADM.L", "DIRECT LINE INSU" : "DLG.L", 
        "SABRE INSUR" : "SBRE.L", "SAGA PLC" : "SAGA.L",
        "AGEAS" : "AGS.BR", 
        
         "ALLIANZ SE-REG" : "ALV.DE", "AXA" : "CS.PA", 
        "ZURICH INSURANCE" : "ZURN.SW", "GENERALI ASSIC" : "G.MI",

        "BEAZLEY PLC" : "BEZ.L", "HISCOX LTD" : "HSX.L", 
        "LANCASHIRE HOLDI" : "LRE.L",

        "Society of Lloyd’s" : "LLOY.L",

        "AMERICAN INTERNA" : "AIG", "AXIS CAPITAL" : "AXS",
        "TRAVELERS COS IN" : "TRV", "ARCH CAPITAL GRP" : "ACGL",
        "RENAISSANCERE" : "RNR", "EVEREST RE GROUP" : "RE",
        "MARKEL CORP" : "MKL", "HARTFORD FINL SV" : "HIG",
        "ARGO GROUP INTER" : "ARGO", "BERKSHIRE HATH-B" : "BRK-B",
        "CHUBB LTD" : "CB",

        "SCOR SE" : "SCR.PA", "MUENCHENER RUE-R" : "MUV2.DE", 
        "SWISS RE AG" : "SREN.SW", "HANNOVER RUECK S" : "HNR1.DE",

        "TOKIO MARINE HD" : "8766.T", "SOMPO HOLDINGS I" : "8630.T",
        "MS&AD INSURANCE" : "8725.T", "QBE INSURANCE" : "QBE.AX",

        "ENSTAR GROUP LTD" : "ESGR", "FAIRFAX FINL HLD" : "FFH.TO", "RANDALL & QUILTE" : "RQIH.L",

        "PRUDENTIAL PLC" : "PRU.L", "M&G PLC" : "MNG.L",
        "LEGAL & GEN GRP" : "LGEN.L", "AVIVA PLC" : "AV.L",
        "PHOENIX GROUP HO" : "PHNX.L", "QUILTER PLC" : "QLT.L",
        "JUST GROUP" : "JUST.L", "ST JAMES'S PLACE" : "STJ.L",
        "AEGON NV" : "AGN.AS", "DISCOVERY LTD" : "DSY.JO",
        "SANLAM LTD" : "SLM.JO",

        "STOREBRAND ASA" : "STB.OL", "CNP ASSURANCES" : "CNP.PA",
        "GJENSIDIGE FORSI" : "GJF.OL", "POSTE ITALIANE" : "PST.MI",
        "NN GROUP" : "NN.AS", "TOPDANMARK A/S" : "TOP.CO",
        "BALOISE HOL-REG" : "BALN.SW", "SAMPO OYJ-A SHS" : "SAMPO.HE",
        "MAPFRE SA" : "MAP.MC", "TRYG A/S" : "TRYG.CO",
        "ASR NEDERLAND NV" : "0RHS.IL", "HELVETIA HOL-REG" : "HELN.SW",
        "INTACT FINANCIAL" : "IFC.TO"
}

company_name_match['Group'] =company_name_match['Real_Company_Name'].map(Groups)
company_name_match['yfiance_ticker'] =company_name_match['Real_Company_Name'].map(yahoo_ticker)
company_name_match
# Out:
#    Real_Company_Name       company_name           Group yfiance_ticker
# 0      ADMIRAL GROUP      Admiral Group  Motor/Personal          ADM.L
# 1   DIRECT LINE INSU        DIRECT LINE  Motor/Personal          DLG.L
# 2        SABRE INSUR       SABRE INSUR-  Motor/Personal         SBRE.L
# 3           SAGA PLC          Saga PLC-  Motor/Personal         SAGA.L
# 4              AGEAS       Ageas SA-NV-  Motor/Personal         AGS.BR
# ..               ...                ...             ...            ...
# 62         MAPFRE SA                NaN  Other insurers         MAP.MC
# 63          TRYG A/S          Tryg A-S-  Other insurers        TRYG.CO
# 64  ASR NEDERLAND NV      ASR Nederland  Other insurers        0RHS.IL
# 65  HELVETIA HOL-REG   Helvetia Holding  Other insurers        HELN.SW
# 66  INTACT FINANCIAL  INTACT FINANCIAL-  Other insurers         IFC.TO
#
# [67 rows x 4 columns]

# %%
df_company = company_name_match[['company_name','Group','yfiance_ticker']]
MD_model_df = df_company.merge(MD_model_df, how='inner', on='company_name')
MD_model_df = MD_model_df.rename(columns={'yfiance_ticker':'ticker'})
MD_model_df
# Out:
#            company_name           Group  ticker  \
# 0         Admiral Group  Motor/Personal   ADM.L
# 1         Admiral Group  Motor/Personal   ADM.L
# 2         Admiral Group  Motor/Personal   ADM.L
# 3         Admiral Group  Motor/Personal   ADM.L
# 4         Admiral Group  Motor/Personal   ADM.L
# ...                 ...             ...     ...
# 1873  INTACT FINANCIAL-  Other insurers  IFC.TO
# 1874  INTACT FINANCIAL-  Other insurers  IFC.TO
# 1875  INTACT FINANCIAL-  Other insurers  IFC.TO
# 1876  INTACT FINANCIAL-  Other insurers  IFC.TO
# 1877  INTACT FINANCIAL-  Other insurers  IFC.TO
#
#                                               file_name        date   topic_1  \
# 0     20110302_Admiral_Group_PLC-_Earnings_Call_2011...  2011-03-02  0.000422
# 1     20110824_Admiral_Group_PLC-_Earnings_Call_2011...  2011-08-24  0.018873
# 2     20111109_Admiral_Group_PLC-_Guidance_Call_2011...  2011-11-09  0.000483
# 3     20111109_Admiral_Group_PLC-_Guidance_Call_2011...  2011-11-09  0.000132
# 4     20120307_Admiral_Group_PLC-_Earnings_Call_2012...  2012-03-07  0.001142
# ...                                                 ...         ...       ...
# 1873  20210210_INTACT_FINANCIAL-_Earnings_Call_2021-...  2021-02-10  0.000540
# 1874  20210512_INTACT_FINANCIAL-_Earnings_Call_2021-...  2021-05-12  0.000448
# 1875  20210728_INTACT_FINANCIAL-_Earnings_Call_2021-...  2021-07-28  0.000409
# 1876  20211110_INTACT_FINANCIAL-_Earnings_Call_2021-...  2021-11-10  0.008767
# 1877  20220209_INTACT_FINANCIAL-_Earnings_Call_2022-...  2022-02-09  0.002885
#
#        topic_2   topic_3   topic_4   topic_5   topic_6   topic_7   topic_8  \
# 0     0.018294  0.014044  0.000324  0.207760  0.075139  0.350356  0.000442
# 1     0.065455  0.002013  0.010815  0.141648  0.174803  0.247567  0.007597
# 2     0.002413  0.002239  0.000597  0.369181  0.325946  0.062897  0.001324
# 3     0.012363  0.000331  0.000164  0.215636  0.209125  0.255078  0.013610
# 4     0.038559  0.022089  0.012813  0.178199  0.106967  0.309508  0.005386
# ...        ...       ...       ...       ...       ...       ...       ...
# 1873  0.021873  0.325021  0.046386  0.000626  0.028170  0.000468  0.021582
# 1874  0.000640  0.338798  0.000553  0.081017  0.011566  0.060326  0.004641
# 1875  0.015842  0.393835  0.059546  0.010670  0.030306  0.008055  0.004261
# 1876  0.048753  0.321927  0.067266  0.107099  0.021305  0.037875  0.004600
# 1877  0.058781  0.373386  0.043808  0.001566  0.054570  0.000387  0.003519
#
#        topic_9  topic_10  topic_11  topic_12  topic_13  topic_14  topic_15  \
# 0     0.135168  0.008782  0.039327  0.000255  0.006920  0.027827  0.000682
# 1     0.038640  0.000299  0.041482  0.082412  0.000745  0.015773  0.008195
# 2     0.026736  0.001349  0.000357  0.034233  0.001572  0.051764  0.088355
# 3     0.100351  0.001297  0.075290  0.003081  0.000290  0.000252  0.003917
# 4     0.069690  0.003642  0.000356  0.002038  0.001019  0.034331  0.010934
# ...        ...       ...       ...       ...       ...       ...       ...
# 1873  0.007641  0.000814  0.027191  0.000456  0.265088  0.001028  0.125830
# 1874  0.019526  0.123964  0.000730  0.000946  0.166146  0.008309  0.153078
# 1875  0.008282  0.069075  0.000302  0.000345  0.169478  0.003321  0.139349
# 1876  0.001614  0.084856  0.008231  0.000406  0.151566  0.016950  0.073491
# 1877  0.015573  0.033835  0.024094  0.013006  0.233980  0.020851  0.110707
#
#       topic_16  topic_17  topic_18  topic_19  topic_20  topic_21  topic_22  \
# 0     0.022554  0.001489  0.019448  0.006159  0.026616  0.009337  0.028654
# 1     0.000727  0.000237  0.002073  0.000710  0.016482  0.103026  0.020430
# 2     0.000193  0.000386  0.007231  0.001175  0.000441  0.020532  0.000595
# 3     0.042913  0.000106  0.048146  0.006038  0.000121  0.004250  0.007512
# 4     0.022572  0.000297  0.056359  0.007962  0.081804  0.002307  0.032027
# ...        ...       ...       ...       ...       ...       ...       ...
# 1873  0.000959  0.000432  0.026091  0.005640  0.000493  0.081956  0.011714
# 1874  0.000179  0.002851  0.015295  0.004423  0.002296  0.003196  0.001070
# 1875  0.000164  0.000795  0.007590  0.003182  0.000373  0.074390  0.000430
# 1876  0.000192  0.000384  0.007920  0.004012  0.016185  0.006674  0.009926
# 1877  0.002618  0.000357  0.000908  0.002603  0.000965  0.000700  0.000902
#
#       WA_sentiment
# 0         0.000395
# 1         0.001340
# 2        -0.000072
# 3         0.000333
# 4         0.002525
# ...            ...
# 1873      0.008551
# 1874      0.006453
# 1875      0.006075
# 1876      0.003757
# 1877      0.006453
#
# [1878 rows x 28 columns]

# %%
start_date='2010-11-01'
end_date='2022-03-02'
stock_list = company_name_match['yfiance_ticker']
df_stock = stock_price_change(stock_list, start_date, end_date)

# limit the dat till 2021-12-31
df_stock = df_stock[df_stock['date']<='2021-12-31']

df_stock
# Out:
# 1 Failed download:
# - CNP.PA: No data found, symbol may be delisted
#            date        Close  ticker       D-1       D+1       D-2       D+2  \
# 0    2010-11-01  1611.000000   ADM.L  0.000000  0.000000  0.000000  0.000000
# 1    2010-11-02  1627.000000   ADM.L  0.009932  0.026429  0.000000  0.000000
# 2    2010-11-03  1670.000000   ADM.L  0.026429  0.005988  0.036623  0.013772
# 3    2010-11-04  1680.000000   ADM.L  0.005988  0.007738  0.032575  0.000000
# 4    2010-11-05  1693.000000   ADM.L  0.007738 -0.007679  0.013772 -0.012995
# ...         ...          ...     ...       ...       ...       ...       ...
# 2798 2021-12-23   163.240005  IFC.TO -0.001101  0.001470  0.001841  0.008025
# 2799 2021-12-24   163.479996  IFC.TO  0.001470  0.006545  0.000367  0.005016
# 2800 2021-12-29   164.550003  IFC.TO  0.006545 -0.001519  0.008025 -0.000790
# 2801 2021-12-30   164.300003  IFC.TO -0.001519  0.000730  0.005016 -0.003530
# 2802 2021-12-31   164.419998  IFC.TO  0.000730 -0.004257 -0.000790 -0.004866
#
#            D-3       D+3       D-5       D+5      D-10      D+10      D-15  \
# 0     0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1     0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2     0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 3     0.042831 -0.005357  0.000000  0.000000  0.000000  0.000000  0.000000
# 4     0
# 2799  0.088818 -0.030943  0.132310 -0.014647  0.110533   0.0   0.0   0.0   0.0
# 2800  0.124947 -0.012364  0.122455 -0.001880  0.108781   0.0   0.0   0.0   0.0
# 2801  0.124163 -0.025504  0.118077 -0.004725  0.106452   0.0   0.0   0.0   0.0
# 2802  0.117261 -0.025313  0.101630 -0.005564  0.098224   0.0   0.0   0.0   0.0
#
# [151708 rows x 51 columns]

# %%
df_stock['date'] = df_stock['date'].astype(str)
# merged company tickers into big dataframe
MD_model_df = MD_model_df.join(df_stock.set_index(["date","ticker"]), 
                         on=["date","ticker"],
                         how='left'
                        )
MD_model_df = MD_model_df.dropna()
MD_model_df = MD_model_df.reset_index(drop=True)
MD_model_df
# Out:
#            company_name           Group  ticker  \
# 0         Admiral Group  Motor/Personal   ADM.L
# 1         Admiral Group  Motor/Personal   ADM.L
# 2         Admiral Group  Motor/Personal   ADM.L
# 3         Admiral Group  Motor/Personal   ADM.L
# 4         Admiral Group  Motor/Personal   ADM.L
# ...                 ...             ...     ...
# 1810  INTACT FINANCIAL-  Other insurers  IFC.TO
# 1811  INTACT FINANCIAL-  Other insurers  IFC.TO
# 1812  INTACT FINANCIAL-  Other insurers  IFC.TO
# 1813  INTACT FINANCIAL-  Other insurers  IFC.TO
# 1814  INTACT FINANCIAL-  Other insurers  IFC.TO
#
#                                               file_name        date   topic_1  \
# 0     20110302_Admiral_Group_PLC-_Earnings_Call_2011...  2011-03-02  0.000422
# 1     20110824_Admiral_Group_PLC-_Earnings_Call_2011...  2011-08-24  0.018873
# 2     20111109_Admiral_Group_PLC-_Guidance_Call_2011...  2011-11-09  0.000483
# 3     20111109_Admiral_Group_PLC-_Guidance_Call_2011...  2011-11-09  0.000132
# 4     20120307_Admiral_Group_PLC-_Earnings_Call_2012...  2012-03-07  0.001142
# ...                                                 ...         ...       ...
# 1810  20201104_INTACT_FINANCIAL-_Earnings_Call_2020-...  2020-11-04  0.000483
# 1811  20210210_INTACT_FINANCIAL-_Earnings_Call_2021-...  2021-02-10  0.000540
# 1812  20210512_INTACT_FINANCIAL-_Earnings_Call_2021-...  2021-05-12  0.000448
# 1813  20210728_INTACT_FINANCIAL-_Earnings_Call_2021-...  2021-07-28  0.000409
# 1814  20211110_INTACT_FINANCIAL-_Earnings_Call_2021-...  2021-11-10  0.008767
#
#        topic_2   topic_3   topic_4   topic_5   topic_6   topic_7   topic_8  \
# 0     0.018294  0.014044  0.000324  0.207760  0.075139  0.350356  0.000442
# 1     0.065455  0.002013  0.010815  0.141648  0.174803  0.247567  0.007597
# 2     0.002413  0.002239  0.000597  0.369181  0.325946  0.062897  0.001324
# 3     0.012363  0.000331  0.000164  0.215636  0.209125  0.255078  0.013610
# 4     0.038559  0.022089  0.012813  0.178199  0.106967  0.309508  0.005386
# ...        ...       ...       ...       ...       ...       ...       ...
# 1810  0.001885  0.314186  0.123143  0.056683  0.037525  0.000419  0.009730
# 1811  0.021873  0.325021  0.046386  0.000626  0.028170  0.000468  0.021582
# 1812  0.000640  0.338798  0.000553  0.081017  0.011566  0.060326  0.004641
# 1813  0.015842  0.393835  0.059546  0.010670  0.030306  0.008055  0.004261
# 1814  0.048753  0.321927  0.067266  0.107099  0.021305  0.037875  0.004600
#
